# %% [markdown]
# # Introduction to Neural Networking in Keras

# %% [markdown]
# We will use the version of Keras that comes in the Tensorflow package, as it has the most up to date tools.

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
from seaborn import heatmap

from sklearn.metrics import mean_squared_error, classification_report,confusion_matrix
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# new libraries
import tensorflow.keras as keras
from keras.models import Sequential
from keras.layers import Dense, Dropout

# %% [markdown]
# # Data
#
# We will be working with 2 different datasets in this project, 1 is a regression dataset and the other is a classification dataset.  This way you can practice doing both using deep learning.
#
# **NOTE**
#
# These datasets are very small for deep learning.  Deep learning models usually work best with very large datasets with at least 10,000 or more samples.  They work best on even larger datasets than that.  But, for demonstration we will use these smaller datasets.
#
# ## Regression
# This is a dataset of housing prices in Boston from 1978.  Each row is a house and the dataset includes several features regarding each house.  Our target today will be the price of the home.

# %%
regression_df = pd.read_csv('https://raw.githubusercontent.com/ninja-josh/image-storage/main/Boston_Housing_from_Sklearn.csv')

# %% [markdown]
# # Regression
#
# Let's start with modeling the regression dataset

# %%
regression_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 7 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     506 non-null    float64
#  1   NOX      506 non-null    float64
#  2   RM       506 non-null    float64
#  3   AGE      506 non-null    float64
#  4   PTRATIO  506 non-null    float64
#  5   LSTAT    506 non-null    float64
#  6   PRICE    506 non-null    float64
# dtypes: float64(7)
# memory usage: 27.8 KB

# %%
regression_df.duplicated().any()
# Out:
# False

# %%
regression_df.describe()
# Out:
#              CRIM         NOX          RM         AGE     PTRATIO       LSTAT  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524    0.554695    6.284634   68.574901   18.455534   12.653063
# std      8.601545    0.115878    0.702617   28.148861    2.164946    7.141062
# min      0.006320    0.385000    3.561000    2.900000   12.600000    1.730000
# 25%      0.082045    0.449000    5.885500   45.025000   17.400000    6.950000
# 50%      0.256510    0.538000    6.208500   77.500000   19.050000   11.360000
# 75%      3.677083    0.624000    6.623500   94.075000   20.200000   16.955000
# max     88.976200    0.871000    8.780000  100.000000   22.000000   37.970000
#
#             PRICE
# count  506.000000
# mean    22.532806
# std      9.197104
# min      5.000000
# 25%     17.025000
# 50%     21.200000
# 75%     25.000000
# max     50.000000

# %%
# Define X and Y and complete the train test split
X = regression_df.drop(columns = 'PRICE')
y = regression_df['PRICE']

X_train, X_test, y_train, y_test = train_test_split(X,y, random_state = 42)

# %% [markdown]
# ## Scaling
#
# Always scale your data for deep learning.  Otherwise you get a problem call 'Exploding Weights'.  Some weights will be updated much faster than others because the inputs are at larger scales.  This tends to hurt learning as data on smaller scales does not update as fast and doesn't get to contribute as much to the decision making process.  By scaling we put all features on the same footing.

# %%
# Scale the data
scaler = StandardScaler()

X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# ### Plot History
#
# Since we will be plotting histories for all of our models, lets create a function to do it quickly.

# %%
# You can use this function to see how your model improves over time
def plot_history(history, metric=None):
  """plot loss and passed metric.  metric is passed as string and must match 'metric'
  argument in the compile step"""
  fig, axes = plt.subplots(2,1, figsize = (5,10))
  axes[0].plot(history.history['loss'], label = "train")
  axes[0].plot(history.history['val_loss'], label='test')
  axes[0].set_title('Loss')
  axes[0].legend()
  if metric:
    axes[1].plot(history.history[metric], label = 'train')
    axes[1].plot(history.history['val_' + metric], label = 'test')
    axes[1].set_title(metric)
    axes[1].legend()

  plt.show()

# %% [markdown]
# ## First Simple Model
#
# We always want to start simple, as deep learning models can get very complex fast and more complex models take more time to train and are more prone to overfitting.  A well performing simple model is better than a well performing complex model.
#
# ## Input layer
# The first layer we will define is not technically the input layer.  We will define the first hidden layer with a special argument that tells Keras how to create a input layer:
#
# `input_dim=`
#
# Input layers can also be defined manually using tensorflow.keras.layers.InputLayer
#
# ## Activation function
#
# For the single hidden layer we will try just 10 nodes and use a ReLU activation.  ReLUs tend to perform well for hidden nodes.
#
# ## Output Layer
#
# For out output layer (last layer) we just use 1 node because we only want 1 number to be outputted.  We will use a linear activation function.  This will simply output the value from the weights and bias in the node with no change.

# %%
X_train.shape[1]
# Out:
# 6

# %%
# Create your model
reg_model = Sequential(name='Regression_NN')
reg_model.add(Dense(10, activation = 'relu', input_dim = X_train.shape[1],name='h1'))
reg_model.add(Dense(1,name='Output'))
reg_model.summary()
# Out:
# Model: "Regression_NN"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  h1 (Dense)                  (None, 10)                70
#
#  Output (Dense)              (None, 1)                 11
#
# =================================================================
# Total params: 81
# Trainable params: 81
# Non-trainable params: 0
# _________________________________________________________________

# %%
visualize_nn(reg_model, description=True, figsize=(13,10))

# %% [markdown]
# ## Compiling
#
# An Adam optimizer is a favorite and often performs well, it's a good place to start.  Our loss function, what our model will try to minimize, as well as our output metrics, what our model history will show, will both be mean squared error.
#
# - Other optimizers : Gradient Descent,Stochastic Gradient Descent,Adagrad,RMSProp

# %%
# Compile your model.  To use the included function, include metrics= ['mse'] in your compilation step
reg_model.compile(optimizer = 'adam', loss = 'mse', metrics = 'mse')

# %% [markdown]
# # Training
#
# Let's try training our model for 100 few epochs.  Sometimes that is enough, and it will give us an idea whether our model is learning anything.

# %%
# Fit your model
history = reg_model.fit(X_train, y_train,
                        validation_data = (X_test, y_test),
                        epochs = 50)
# Out:
# Epoch 1/50
# 12/12 [==============================] - 1s 20ms/step - loss: 596.6746 - mse: 596.6746 - val_loss: 512.5927 - val_mse: 512.5927
# Epoch 2/50
# 12/12 [==============================] - 0s 4ms/step - loss: 591.7172 - mse: 591.7172 - val_loss: 507.9857 - val_mse: 507.9857
# Epoch 3/50
# 12/12 [==============================] - 0s 4ms/step - loss: 586.6609 - mse: 586.6609 - val_loss: 503.3367 - val_mse: 503.3367
# Epoch 4/50
# 12/12 [==============================] - 0s 4ms/step - loss: 581.5920 - mse: 581.5920 - val_loss: 498.6589 - val_mse: 498.6589
# Epoch 5/50
# 12/12 [==============================] - 0s 6ms/step - loss: 576.3677 - mse: 576.3677 - val_loss: 493.8752 - val_mse: 493.8752
# Epoch 6/50
# 12/12 [==============================] - 0s 5ms/step - loss: 571.1068 - mse: 571.1068 - val_loss: 488.9753 - val_mse: 488.9753
# Epoch 7/50
# 12/12 [==============================] - 0s 4ms/step - loss: 565.4915 - mse: 565.4915 - val_loss: 484.0180 - val_mse: 484.0180
# Epoch 8/50
# 12/12 [==============================] - 0s 4ms/step - loss: 559.8204 - mse: 559.8204 - val_loss: 478.8700 - val_mse: 478.8700
# Epoch 9/50
# 12/12 [==============================] - 0s 5ms/step - loss: 553.8169 - mse: 553.8169 - val_loss: 473.6071 - val_mse: 473.6071
# Epoch 10/50
# 12/12 [==============================] - 0s 4ms/step - loss: 547.6650 - mse: 547.6650 - val_loss: 468.1962 - val_mse: 468.1962
# Epoch 11/50
plot_history(history, 'mse')

# %% [markdown]
# ## Evaluation

# %%
# Make predictions and evaluate your model
train_preds = reg_model.predict(X_train)
test_preds = reg_model.predict(X_test)

print('training rmse:', np.sqrt(mean_squared_error(y_train, train_preds)))
print('testing rmse:', np.sqrt(mean_squared_error(y_test, test_preds)))
# Out:
# training rmse: 13.686946407241123
# testing rmse: 12.65013426085404

# %% [markdown]
# # Classification:
#
# Classification models are similar, except that we need to adjust the final activation of the output layer, the loss function in the compile step, and the metrics we use to judge them.  Remember: MAE, MSE, RMSE, and R2 are regression metrics, accuracy, recall, precision, F1-Score, and confusion matrices are classification metrics.
#
# ## Classification Dataset
# The classification dataset describes diabetes rates among Pima Indians.  Each row is a person and this dataset and includes features regarding health related measurements.  The target binary and represents whether or not a person will diagnosed with diabetes.  This is another old dataset first presented in 1988.

# %%
classification_df = pd.read_csv('https://raw.githubusercontent.com/ninja-josh/image-storage/main/diabetes.csv')
classification_df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
classification_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
classification_df.duplicated().any()
# Out:
# False

# %%
classification_df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# min      0.000000                  0.078000   21.000000    0.000000
# 25%     27.300000                  0.243750   24.000000    0.000000
# 50%     32.000000                  0.372500   29.000000    0.000000
# 75%     36.600000                  0.626250   41.000000    1.000000
# max     67.100000                  2.420000   81.000000    1.000000

# %% [markdown]
# We see minimums for Glucose, BloodPression, SkinThickness, Insulin, and BMI of 0s.  Those are impossible for humans, so lets drop those rows.

# %%
no_glucose = classification_df['Glucose'] == 0
no_blood = classification_df['BloodPressure'] == 0
no_skin = classification_df['SkinThickness'] == 0
no_insulin = classification_df['Insulin'] == 0
no_bmi = classification_df['BMI'] == 0

#class_df_clean excludes rows that have no values == 0 in the above columns
class_df_clean = classification_df[~(no_glucose |
                                     no_blood |
                                     no_skin |
                                     no_insulin |
                                     no_bmi)]
class_df_clean.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   392.000000  392.000000     392.000000     392.000000  392.000000
# mean      3.301020  122.627551      70.663265      29.145408  156.056122
# std       3.211424   30.860781      12.496092      10.516424  118.841690
# min       0.000000   56.000000      24.000000       7.000000   14.000000
# 25%       1.000000   99.000000      62.000000      21.000000   76.750000
# 50%       2.000000  119.000000      70.000000      29.000000  125.500000
# 75%       5.000000  143.000000      78.000000      37.000000  190.000000
# max      17.000000  198.000000     110.000000      63.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  392.000000                392.000000  392.000000  392.000000
# mean    33.086224                  0.523046   30.864796    0.331633
# std      7.027659                  0.345488   10.200777    0.471401
# min     18.200000                  0.085000   21.000000    0.000000
# 25%     28.400000                  0.269750   23.000000    0.000000
# 50%     33.200000                  0.449500   27.000000    0.000000
# 75%     37.100000                  0.687000   36.000000    1.000000
# max     67.100000                  2.420000   81.000000    1.000000

# %% [markdown]
# We lost a lot of data, going from 768 samples to 392 samples.  In the future we might impute this data using means, medians, or other imputation strategies.  For this exercise we won't focus on that.

# %%
# Define X and y and train test split
X = class_df_clean.drop(columns = 'Outcome')
y = class_df_clean['Outcome']

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 42, stratify = y)

# %%
# Scale the data
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# ## Classification Model
#
# We need to do a few things differently here:
#
# Since this is a binary classification, the activation of our final layer needs to be 'sigmoid'.  If this were multiclass we would set this as 'softmax' and the number of output nodes would be the number of classes in our y_train.

# %%
# Build your model
n_cols = X_train.shape[1]
class_model = Sequential(name='Classification')
class_model.add(Dense(10, activation = 'relu', input_dim = X_train.shape[1]))
class_model.add(Dense(10, activation = 'relu'))
class_model.add(Dense(1, activation = 'sigmoid'))
class_model.summary()
# Out:
# Model: "Classification"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 10)                90
#
#  dense_1 (Dense)             (None, 10)                110
#
#  dense_2 (Dense)             (None, 1)                 11
#
# =================================================================
# Total params: 211
# Trainable params: 211
# Non-trainable params: 0
# _________________________________________________________________

# %%
visualize_nn(class_model, description=True, figsize=(10,8))

# %% [markdown]
# We need to change our loss to 'binary_crossentropy'.  If this were multiclass we would use 'categorical_crossentrobpy'.
#
# Since MSE is a regression metric, not a classification metric, we change the metric to accuracy.  We could also use recall or precision.

# %%
# # Compile your model, set metrics = ['acc']

class_model.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# %%
# fit your model
history = class_model.fit(X_train, y_train,
                        validation_data = (X_test, y_test),
                        epochs = 100)
# Out:
# Epoch 1/100
# 10/10 [==============================] - 1s 25ms/step - loss: 0.7629 - accuracy: 0.6599 - val_loss: 0.7307 - val_accuracy: 0.6735
# Epoch 2/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.7356 - accuracy: 0.6633 - val_loss: 0.7099 - val_accuracy: 0.6735
# Epoch 3/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.7120 - accuracy: 0.6667 - val_loss: 0.6916 - val_accuracy: 0.6735
# Epoch 4/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.6895 - accuracy: 0.6667 - val_loss: 0.6763 - val_accuracy: 0.6735
# Epoch 5/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.6712 - accuracy: 0.6667 - val_loss: 0.6628 - val_accuracy: 0.6735
# Epoch 6/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.6542 - accuracy: 0.6701 - val_loss: 0.6505 - val_accuracy: 0.6735
# Epoch 7/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.6388 - accuracy: 0.6701 - val_loss: 0.6388 - val_accuracy: 0.6735
# Epoch 8/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.6247 - accuracy: 0.6735 - val_loss: 0.6277 - val_accuracy: 0.6735
# Epoch 9/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.6110 - accuracy: 0.6735 - val_loss: 0.6175 - val_accuracy: 0.6735
# Epoch 10/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.5974 - accuracy: 0.6735 - val_loss: 0.6079 - val_accuracy: 0.6735
# Epoch 11/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.5847 - accuracy: 0.6769 - val_loss: 0.5992 - val_accuracy: 0.6837
# Epoch 12/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.5720 - accuracy: 0.6837 - val_loss: 0.5908 - val_accuracy: 0.6837
# Epoch 13/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.5600 - accuracy: 0.6837 - val_loss: 0.5828 - val_accuracy: 0.6939
# Epoch 14/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.5490 - accuracy: 0.6871 - val_loss: 0.5752 - val_accuracy: 0.6939
# Epoch 15/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.5381 - accuracy: 0.6803 - val_loss: 0.5683 - val_accuracy: 0.6939
# Epoch 16/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.5281 - accuracy: 0.6803 - val_loss: 0.5621 - val_accuracy: 0.7041
# Epoch 17/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.5181 - accuracy: 0.6905 - val_loss: 0.5564 - val_accuracy: 0.7041
# Epoch 18/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.5096 - accuracy: 0.6871 - val_loss: 0.5512 - val_accuracy: 0.7041
# Epoch 19/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.5012 - accuracy: 0.6905 - val_loss: 0.5454 - val_accuracy: 0.6939
# Epoch 20/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.4924 - accuracy: 0.7075 - val_loss: 0.5399 - val_accuracy: 0.7245
# Epoch 21/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.4845 - accuracy: 0.7041 - val_loss: 0.5354 - val_accuracy: 0.7449
# Epoch 22/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.4767 - accuracy: 0.7109 - val_loss: 0.5310 - val_accuracy: 0.7449
# Epoch 23/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.4699 - accuracy: 0.7415 - val_loss: 0.5272 - val_accuracy: 0.7755
# Epoch 24/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.4628 - accuracy: 0.7449 - val_loss: 0.5241 - val_accuracy: 0.7551
# Epoch 25/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.4562 - accuracy: 0.7449 - val_loss: 0.5209 - val_accuracy: 0.7653
# Epoch 26/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.4505 - accuracy: 0.7585 - val_loss: 0.5177 - val_accuracy: 0.7653
# Epoch 27/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.4453 - accuracy: 0.7721 - val_loss: 0.5163 - val_accuracy: 0.7755
# Epoch 28/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.4399 - accuracy: 0.7857 - val_loss: 0.5146 - val_accuracy: 0.7755
# Epoch 29/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.4355 - accuracy: 0.7959 - val_loss: 0.5126 - val_accuracy: 0.7755
# Epoch 30/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.4320 - accuracy: 0.7993 - val_loss: 0.5126 - val_accuracy: 0.7653
# Epoch 31/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.4287 - accuracy: 0.8027 - val_loss: 0.5119 - val_accuracy: 0.7653
# Epoch 32/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.4254 - accuracy: 0.7993 - val_loss: 0.5115 - val_accuracy: 0.7653
# Epoch 33/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.4225 - accuracy: 0.8027 - val_loss: 0.5115 - val_accuracy: 0.7653
# Epoch 34/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.4200 - accuracy: 0.7993 - val_loss: 0.5114 - val_accuracy: 0.7653
# Epoch 35/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.4176 - accuracy: 0.7993 - val_loss: 0.5124 - val_accuracy: 0.7551
# Epoch 36/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.4150 - accuracy: 0.7925 - val_loss: 0.5118 - val_accuracy: 0.7551
# Epoch 37/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.4127 - accuracy: 0.7993 - val_loss: 0.5120 - val_accuracy: 0.7449
# Epoch 38/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.4114 - accuracy: 0.7925 - val_loss: 0.5135 - val_accuracy: 0.7449
# Epoch 39/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.4093 - accuracy: 0.7993 - val_loss: 0.5137 - val_accuracy: 0.7449
# Epoch 40/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.4070 - accuracy: 0.7959 - val_loss: 0.5151 - val_accuracy: 0.7449
# Epoch 41/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.4055 - accuracy: 0.7993 - val_loss: 0.5167 - val_accuracy: 0.7347
# Epoch 42/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.4042 - accuracy: 0.7959 - val_loss: 0.5172 - val_accuracy: 0.7449
# Epoch 43/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.4028 - accuracy: 0.7925 - val_loss: 0.5178 - val_accuracy: 0.7449
# Epoch 44/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.4010 - accuracy: 0.7925 - val_loss: 0.5187 - val_accuracy: 0.7449
# Epoch 45/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.3998 - accuracy: 0.7925 - val_loss: 0.5189 - val_accuracy: 0.7449
# Epoch 46/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.3986 - accuracy: 0.7925 - val_loss: 0.5192 - val_accuracy: 0.7449
# Epoch 47/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.3972 - accuracy: 0.7959 - val_loss: 0.5195 - val_accuracy: 0.7449
# Epoch 48/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.3960 - accuracy: 0.7959 - val_loss: 0.5203 - val_accuracy: 0.7449
# Epoch 49/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.3948 - accuracy: 0.7959 - val_loss: 0.5204 - val_accuracy: 0.7449
# Epoch 50/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.3938 - accuracy: 0.7993 - val_loss: 0.5205 - val_accuracy: 0.7449
# Epoch 51/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.3929 - accuracy: 0.7993 - val_loss: 0.5209 - val_accuracy: 0.7449
# Epoch 52/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.3919 - accuracy: 0.7993 - val_loss: 0.5208 - val_accuracy: 0.7449
# Epoch 53/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.3910 - accuracy: 0.8027 - val_loss: 0.5219 - val_accuracy: 0.7449
# Epoch 54/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.3898 - accuracy: 0.7993 - val_loss: 0.5226 - val_accuracy: 0.7449
# Epoch 55/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.3888 - accuracy: 0.7993 - val_loss: 0.5233 - val_accuracy: 0.7449
# Epoch 56/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.3875 - accuracy: 0.8061 - val_loss: 0.5242 - val_accuracy: 0.7449
# Epoch 57/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.3865 - accuracy: 0.8061 - val_loss: 0.5252 - val_accuracy: 0.7449
# Epoch 58/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.3858 - accuracy: 0.7993 - val_loss: 0.5245 - val_accuracy: 0.7449
# Epoch 59/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.3852 - accuracy: 0.7959 - val_loss: 0.5244 - val_accuracy: 0.7449
# Epoch 60/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.3840 - accuracy: 0.7993 - val_loss: 0.5256 - val_accuracy: 0.7449
# Epoch 61/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.3829 - accuracy: 0.8027 - val_loss: 0.5279 - val_accuracy: 0.7347
# Epoch 62/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.3819 - accuracy: 0.8095 - val_loss: 0.5293 - val_accuracy: 0.7347
# Epoch 63/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.3813 - accuracy: 0.8095 - val_loss: 0.5298 - val_accuracy: 0.7347
# Epoch 64/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.3805 - accuracy: 0.8129 - val_loss: 0.5307 - val_accuracy: 0.7245
# Epoch 65/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.3797 - accuracy: 0.8129 - val_loss: 0.5317 - val_accuracy: 0.7143
# Epoch 66/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.3786 - accuracy: 0.8163 - val_loss: 0.5317 - val_accuracy: 0.7143
# Epoch 67/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.3777 - accuracy: 0.8095 - val_loss: 0.5318 - val_accuracy: 0.7245
# Epoch 68/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.3769 - accuracy: 0.8061 - val_loss: 0.5322 - val_accuracy: 0.7143
# Epoch 69/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.3759 - accuracy: 0.8095 - val_loss: 0.5331 - val_accuracy: 0.7245
# Epoch 70/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.3751 - accuracy: 0.8129 - val_loss: 0.5328 - val_accuracy: 0.7245
# Epoch 71/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.3742 - accuracy: 0.8129 - val_loss: 0.5323 - val_accuracy: 0.7245
# Epoch 72/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.3735 - accuracy: 0.8095 - val_loss: 0.5325 - val_accuracy: 0.7245
# Epoch 73/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.3728 - accuracy: 0.8095 - val_loss: 0.5328 - val_accuracy: 0.7245
# Epoch 74/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.3721 - accuracy: 0.8095 - val_loss: 0.5336 - val_accuracy: 0.7245
# Epoch 75/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.3711 - accuracy: 0.8095 - val_loss: 0.5343 - val_accuracy: 0.7245
# Epoch 76/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.3703 - accuracy: 0.8129 - val_loss: 0.5356 - val_accuracy: 0.7245
# Epoch 77/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.3696 - accuracy: 0.8129 - val_loss: 0.5362 - val_accuracy: 0.7245
# Epoch 78/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.3689 - accuracy: 0.8129 - val_loss: 0.5386 - val_accuracy: 0.7143
# Epoch 79/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.3687 - accuracy: 0.8197 - val_loss: 0.5400 - val_accuracy: 0.7143
# Epoch 80/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.3678 - accuracy: 0.8197 - val_loss: 0.5391 - val_accuracy: 0.7143
# Epoch 81/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.3667 - accuracy: 0.8197 - val_loss: 0.5386 - val_accuracy: 0.7245
# Epoch 82/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.3661 - accuracy: 0.8163 - val_loss: 0.5384 - val_accuracy: 0.7245
# Epoch 83/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.3650 - accuracy: 0.8197 - val_loss: 0.5373 - val_accuracy: 0.7347
# Epoch 84/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.3642 - accuracy: 0.8163 - val_loss: 0.5368 - val_accuracy: 0.7449
# Epoch 85/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.3635 - accuracy: 0.8163 - val_loss: 0.5377 - val_accuracy: 0.7449
# Epoch 86/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.3630 - accuracy: 0.8197 - val_loss: 0.5376 - val_accuracy: 0.7551
# Epoch 87/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.3625 - accuracy: 0.8197 - val_loss: 0.5388 - val_accuracy: 0.7551
# Epoch 88/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.3612 - accuracy: 0.8231 - val_loss: 0.5393 - val_accuracy: 0.7551
# Epoch 89/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.3601 - accuracy: 0.8163 - val_loss: 0.5383 - val_accuracy: 0.7551
# Epoch 90/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.3598 - accuracy: 0.8197 - val_loss: 0.5384 - val_accuracy: 0.7551
# Epoch 91/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.3585 - accuracy: 0.8197 - val_loss: 0.5397 - val_accuracy: 0.7551
# Epoch 92/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.3578 - accuracy: 0.8231 - val_loss: 0.5405 - val_accuracy: 0.7551
# Epoch 93/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.3571 - accuracy: 0.8231 - val_loss: 0.5410 - val_accuracy: 0.7551
# Epoch 94/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.3562 - accuracy: 0.8231 - val_loss: 0.5415 - val_accuracy: 0.7347
# Epoch 95/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.3559 - accuracy: 0.8265 - val_loss: 0.5406 - val_accuracy: 0.7551
# Epoch 96/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.3550 - accuracy: 0.8299 - val_loss: 0.5423 - val_accuracy: 0.7449
# Epoch 97/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.3541 - accuracy: 0.8333 - val_loss: 0.5419 - val_accuracy: 0.7551
# Epoch 98/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.3534 - accuracy: 0.8333 - val_loss: 0.5414 - val_accuracy: 0.7551
# Epoch 99/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.3531 - accuracy: 0.8299 - val_loss: 0.5406 - val_accuracy: 0.7551
# Epoch 100/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.3519 - accuracy: 0.8299 - val_loss: 0.5414 - val_accuracy: 0.7551

# %%
# See how your model is doing
plot_history(history, 'accuracy')

# %% [markdown]
# ## Evaluation

# %%
# Make predicitons and evaluate your model
print('Training Scores')

# Define labels for the confusion matrix
labels = ['No Diabetes', 'Diabetes']

# Get training predictions and round them to integers instead of floats
train_preds = np.rint(class_model.predict(X_train))

# Classification Report
print(classification_report(y_train, train_preds))

# Confusion Matrix
conf_mat = confusion_matrix(y_train, train_preds, normalize='true')
heatmap(conf_mat, xticklabels=labels, yticklabels=labels, annot=True)
plt.show()
print('\n')
print('Testing Scores')

# Get testing predictions and round them to integers
test_preds = np.rint(class_model.predict(X_test))

# Classification report
print(classification_report(y_test, test_preds))

# Confusion Matrix
conf_mat = confusion_matrix(y_test, test_preds, normalize='true')
heatmap(conf_mat, xticklabels=labels, yticklabels=labels, annot=True)
plt.show()
# Out:
# Training Scores
#               precision    recall  f1-score   support
#
#            0       0.88      0.86      0.87       196
#            1       0.74      0.77      0.75        98
#
#     accuracy                           0.83       294
#    macro avg       0.81      0.81      0.81       294
# weighted avg       0.83      0.83      0.83       294
# Testing Scores
#               precision    recall  f1-score   support
#
#            0       0.84      0.79      0.81        66
#            1       0.61      0.69      0.65        32
#
#     accuracy                           0.76        98
#    macro avg       0.72      0.74      0.73        98
# weighted avg       0.76      0.76      0.76        98

# %% [markdown]
# You can find source of this visual function from here :[source](https://towardsdatascience.com/deep-learning-with-python-neural-networks-complete-tutorial-6b53c0b06af0)

# %%
'''
Extract info for each layer in a keras model.
'''
def utils_nn_config(model):
    lst_layers = []
    if "Sequential" in str(model): #-> Sequential doesn't show the input layer
        layer = model.layers[0]
        lst_layers.append({"name":"input", "in":int(layer.input.shape[-1]), "neurons":0, 
                           "out":int(layer.input.shape[-1]), "activation":None,
                           "params":0, "bias":0})
    for layer in model.layers:
        try:
            dic_layer = {"name":layer.name, "in":int(layer.input.shape[-1]), "neurons":layer.units, 
                         "out":int(layer.output.shape[-1]), "activation":layer.get_config()["activation"],
                         "params":layer.get_weights()[0], "bias":layer.get_weights()[1]}
        except:
            dic_layer = {"name":layer.name, "in":int(layer.input.shape[-1]), "neurons":0, 
                         "out":int(layer.output.shape[-1]), "activation":None,
                         "params":0, "bias":0}
        lst_layers.append(dic_layer)
    return lst_layers

def visualize_nn(model, description=False, figsize=(10,8)):
    ## get layers info
    lst_layers = utils_nn_config(model)
    layer_sizes = [layer["out"] for layer in lst_layers]
    
    ## fig setup
    fig = plt.figure(figsize=figsize)
    ax = fig.gca()
    ax.set(title=model.name)
    ax.axis('off')
    left, right, bottom, top = 0.1, 0.9, 0.1, 0.9
    x_space = (right-left) / float(len(layer_sizes)-1)
    y_space = (top-bottom) / float(max(layer_sizes))
    p = 0.025
    
    ## nodes
    for i,n in enumerate(layer_sizes):
        top_on_layer = y_space*(n-1)/2.0 + (top+bottom)/2.0
        layer = lst_layers[i]
        color = "green" if i in [0, len(layer_sizes)-1] else "blue"
        color = "red" if (layer['neurons'] == 0) and (i > 0) else color
        
        ### add description
        if (description is True):
            d = i if i == 0 else i-0.5
            if layer['activation'] is None:
                plt.text(x=left+d*x_space, y=top, fontsize=10, color=color, s=layer["name"].upper())
            else:
                plt.text(x=left+d*x_space, y=top, fontsize=10, color=color, s=layer["name"].upper())
                plt.text(x=left+d*x_space, y=top-p, fontsize=10, color=color, s=layer['activation']+" (")
                plt.text(x=left+d*x_space, y=top-2*p, fontsize=10, color=color, s="Σ"+str(layer['in'])+"[X*w]+b")
                out = " Y"  if i == len(layer_sizes)-1 else " out"
                plt.text(x=left+d*x_space, y=top-3*p, fontsize=10, color=color, s=") = "+str(layer['neurons'])+out)
        
        ### circles
        for m in range(n):
            color = "limegreen" if color == "green" else color
            circle = plt.Circle(xy=(left+i*x_space, top_on_layer-m*y_space-4*p), radius=y_space/4.0, color=color, ec='k', zorder=4)
            ax.add_artist(circle)
            
            ### add text
            if i == 0:
                plt.text(x=left-4*p, y=top_on_layer-m*y_space-4*p, fontsize=10, s=r'$X_{'+str(m+1)+'}$')
            elif i == len(layer_sizes)-1:
                plt.text(x=right+4*p, y=top_on_layer-m*y_space-4*p, fontsize=10, s=r'$y_{'+str(m+1)+'}$')
            else:
                plt.text(x=left+i*x_space+p, y=top_on_layer-m*y_space+(y_space/8.+0.01*y_space)-4*p, fontsize=10, s=r'$H_{'+str(m+1)+'}$')
    
    ## links
    for i, (n_a, n_b) in enumerate(zip(layer_sizes[:-1], layer_sizes[1:])):
        layer = lst_layers[i+1]
        color = "green" if i == len(layer_sizes)-2 else "blue"
        color = "red" if layer['neurons'] == 0 else color
        layer_top_a = y_space*(n_a-1)/2. + (top+bottom)/2. -4*p
        layer_top_b = y_space*(n_b-1)/2. + (top+bottom)/2. -4*p
        for m in range(n_a):
            for o in range(n_b):
                line = plt.Line2D([i*x_space+left, (i+1)*x_space+left], 
                                  [layer_top_a-m*y_space, layer_top_b-o*y_space], 
                                  c=color, alpha=0.5)
                if layer['activation'] is None:
                    if o == m:
                        ax.add_artist(line)
                else:
                    ax.add_artist(line)
    plt.show()
