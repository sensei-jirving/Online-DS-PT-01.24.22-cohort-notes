# %% [markdown]
# # Introduction to Neural Networking in Keras

# %% [markdown]
# We will use the version of Keras that comes in the Tensorflow package, as it has the most up to date tools.

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
from seaborn import heatmap

from sklearn.metrics import mean_squared_error, classification_report,confusion_matrix,r2_score
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.compose import make_column_selector,make_column_transformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.linear_model import LinearRegression

import tensorflow.keras as keras
from keras.models import Sequential
from keras.layers import Dense

# %% [markdown]
# # Data
#
# We will be working with 2 different datasets in this project, 1 is a regression dataset and the other is a classification dataset.  This way you can practice doing both using deep learning.
#
# **NOTE**
#
# These datasets are very small for deep learning.  Deep learning models usually work best with very large datasets with at least 10,000 or more samples.  They work best on even larger datasets than that.  But, for demonstration we will use these smaller datasets.
#
# ## Regression
# This is a dataset of medical charges based on age,sex,bmi, no of children, weather the person is smoker or not and region. Our target today will be the charges.

# %%
regression_df = pd.read_csv("https://docs.google.com/spreadsheets/d/e/2PACX-1vQJQrxI5M5hb0TVJu665uuiBUKKIHbjrBROTmiH7HJLpAvw8yRylx0vpin0Qt1LruZVC2IpO2z1yKfd/pub?output=csv")
regression_df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %% [markdown]
# # Regression
#
# Let's start with modeling the regression dataset

# %%
regression_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
regression_df.isna().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
regression_df.duplicated().any()
# Out:
# True

# %%
regression_df.drop_duplicates(inplace=True)

# %%
regression_df.describe()
# Out:
#                age          bmi     children       charges
# count  1337.000000  1337.000000  1337.000000   1337.000000
# mean     39.222139    30.663452     1.095737  13279.121487
# std      14.044333     6.100468     1.205571  12110.359656
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.290000     0.000000   4746.344000
# 50%      39.000000    30.400000     1.000000   9386.161300
# 75%      51.000000    34.700000     2.000000  16657.717450
# max      64.000000    53.130000     5.000000  63770.428010

# %%
# Define X and Y and complete the train test split
X = regression_df.drop(columns = 'charges')
y = regression_df['charges']

X_train, X_test, y_train, y_test = train_test_split(X,y, random_state = 42)

# %%
#instantiate
scaler = StandardScaler()
ohe = OneHotEncoder (handle_unknown='ignore', sparse = False)

#make column selector
cat_selector = make_column_selector(dtype_include='object')
num_selector = make_column_selector(dtype_include='number')

#tuples
num_tuple = (scaler, num_selector)
cat_tuple = (ohe, cat_selector)

#column transform
preprocessed = make_column_transformer(num_tuple, cat_tuple, remainder='passthrough')

# %%
# Fit and transform data
X_train = preprocessed.fit_transform(X_train)
X_test = preprocessed.transform(X_test)

# %% [markdown]
# ### Plot History
#
# Since we will be plotting histories for all of our models, lets create a function to do it quickly.

# %%
#  You can use this function to see how your model improves over time
def plot_history(history, metric=None):
  """plot loss and passed metric.  metric is passed as string and must match 'metric'
  argument in the compile step"""
  fig, axes = plt.subplots(2,1, figsize = (5,10))
  axes[0].plot(history.history['loss'], label = "train")
  axes[0].plot(history.history['val_loss'], label='test')
  axes[0].set_title('Loss')
  axes[0].legend()
  if metric:
    axes[1].plot(history.history[metric], label = 'train')
    axes[1].plot(history.history['val_' + metric], label = 'test')
    axes[1].set_title(metric)
    axes[1].legend()

  plt.show()

# %% [markdown]
# ## First Simple Model
#
# We always want to start simple, as deep learning models can get very complex fast and more complex models take more time to train and are more prone to overfitting.  A well performing simple model is better than a well performing complex model.
#
# ## Input layer
# The first layer we will define is not technically the input layer.  We will define the first hidden layer with a special argument that tells Keras how to create a hidden input layer:
#
# `input_dim=`
#
# ## Activations
#
# For the single hidden layer we will try just 10 nodes and use a ReLU activation.  ReLUs tend to perform well for hidden nodes. Linear activation function is used for regression problems.
#
# ## Output Layer
#
# For out output layer (last layer) we just use 1 node because we only want 1 number to be outputted.  We will use a linear activation function.  This will simply output the value from the weights and bias in the node with no change.

# %%
# Create your model
reg_model = Sequential()
reg_model.add(Dense(10, activation = 'relu', input_dim = X_train.shape[1]))
reg_model.add(Dense(8,activation = 'linear'))
reg_model.add(Dense(1))
reg_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 10)                120
#
#  dense_1 (Dense)             (None, 8)                 88
#
#  dense_2 (Dense)             (None, 1)                 9
#
# =================================================================
# Total params: 217
# Trainable params: 217
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Compiling
#
# An Adam optimizer is a favorite and often performs well, it's a good place to start.  Our loss function, what our model will try to minimize, as well as our output metrics, what our model history will show, will both be mean squared error.

# %%
# Compile your model
reg_model.compile(optimizer = 'adam', loss = 'mse', metrics = ['mae'])

# %% [markdown]
# # Training
#
# Let's try training our model for 100 few epochs.  Sometimes that is enough, and it will give us an idea whether our model is learning anything.

# %%
# Fit your model
history = reg_model.fit(X_train, y_train,
                        validation_data = (X_test, y_test),
                        epochs = 100,verbose=0)

# %%
# Apply the custom function to see how your model is doing
plot_history(history, 'mse')

# %% [markdown]
# ## Evaluation

# %%
# Make predictions and evaluate your model
train_preds = reg_model.predict(X_train)
test_preds = reg_model.predict(X_test)

print('training rmse:', np.sqrt(mean_squared_error(y_train, train_preds)))
print('testing rmse:', np.sqrt(mean_squared_error(y_test, test_preds)))
# Out:
# training rmse: 9701.765613089347
# testing rmse: 10588.018650315267

# %%
print(f"Train R-Squared: { r2_score(y_train, train_preds)}")
print(f"Test R-Squared: { r2_score(y_test, test_preds)}")
# Out:
# Train R-Squared: 0.31587774882468744
# Test R-Squared: 0.3516496497403544

# %% [markdown]
# It seem our model has not yet bottomed out in learning.  This indicates we should train it longer.
#
# As long as we don't recompile our model, we can just fit it again and it will pick up the training where it left off

# %% [markdown]
# # Classification:
#
# Classification models are similar, except that we need to adjust the final activation of the output layer, the loss function in the compile step, and the metrics we use to judge them.  Remember: MAE, MSE, RMSE, and R2 are regression metrics, accuracy, recall, precision, F1-Score, and confusion matrices are classification metrics.
#
# ## Classification Dataset
# The classification dataset describes diabetes rates among Pima Indians.  Each row is a person and this dataset and includes features regarding health related measurements.  The target binary and represents whether or not a person will diagnosed with diabetes.  This is another old dataset first presented in 1988.

# %%
classification_df = pd.read_csv('https://raw.githubusercontent.com/ninja-josh/image-storage/main/diabetes.csv')
classification_df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
classification_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
classification_df.duplicated().any()
# Out:
# False

# %%
classification_df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# min      0.000000                  0.078000   21.000000    0.000000
# 25%     27.300000                  0.243750   24.000000    0.000000
# 50%     32.000000                  0.372500   29.000000    0.000000
# 75%     36.600000                  0.626250   41.000000    1.000000
# max     67.100000                  2.420000   81.000000    1.000000

# %% [markdown]
# We see minimums for Glucose, BloodPression, SkinThickness, Insulin, and BMI of 0s.  Those are impossible for humans, so lets drop those rows.

# %%
no_glucose = classification_df['Glucose'] == 0
no_blood = classification_df['BloodPressure'] == 0
no_skin = classification_df['SkinThickness'] == 0
no_insulin = classification_df['Insulin'] == 0
no_bmi = classification_df['BMI'] == 0

#class_df_clean excludes rows that have no values == 0 in the above columns
class_df_clean = classification_df[~(no_glucose |
                                     no_blood |
                                     no_skin |
                                     no_insulin |
                                     no_bmi)]
class_df_clean.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   392.000000  392.000000     392.000000     392.000000  392.000000
# mean      3.301020  122.627551      70.663265      29.145408  156.056122
# std       3.211424   30.860781      12.496092      10.516424  118.841690
# min       0.000000   56.000000      24.000000       7.000000   14.000000
# 25%       1.000000   99.000000      62.000000      21.000000   76.750000
# 50%       2.000000  119.000000      70.000000      29.000000  125.500000
# 75%       5.000000  143.000000      78.000000      37.000000  190.000000
# max      17.000000  198.000000     110.000000      63.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  392.000000                392.000000  392.000000  392.000000
# mean    33.086224                  0.523046   30.864796    0.331633
# std      7.027659                  0.345488   10.200777    0.471401
# min     18.200000                  0.085000   21.000000    0.000000
# 25%     28.400000                  0.269750   23.000000    0.000000
# 50%     33.200000                  0.449500   27.000000    0.000000
# 75%     37.100000                  0.687000   36.000000    1.000000
# max     67.100000                  2.420000   81.000000    1.000000

# %% [markdown]
# We lost a lot of data, going from 768 samples to 392 samples.  In the future we might impute this data using means, medians, or other imputation strategies.  For this exercise we won't focus on that.

# %%
# Define X and y and train test split
X = class_df_clean.drop(columns = 'Outcome')
y = class_df_clean['Outcome']

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 42, stratify = y)

# %%
# Scale
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# ## Classification Model
#
# We need to do a few things differently here:
#
# Since this is a binary classification, the activation of our final layer needs to be 'sigmoid'.  If this were multiclass we would set this as 'softmax' and the number of output nodes would be the number of classes in our y_train.

# %%
# Build your model
# Create your model
n_cols = X_train.shape[1]
class_model = Sequential()
class_model.add(Dense(10, activation = 'relu', input_dim = X_train.shape[1]))
class_model.add(Dense(10, activation = 'relu'))
class_model.add(Dense(1, activation = 'sigmoid'))

# %% [markdown]
# We need to change our loss to 'binary_crossentropy'.  If this were multiclass we would use 'categorical_crossentropy'.
#
# Since MSE is a regression metric, not a classification metric, we change the metric to accuracy.  We could also use recall or precision.

# %%
# Compile your model, to use our custom function, set metrics = ['acc']
class_model.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# %%
# fit your model
history = class_model.fit(X_train, y_train,
                        validation_data = (X_test, y_test),
                        epochs = 70)
# Out:
# Epoch 1/70
# 10/10 [==============================] - 1s 18ms/step - loss: 0.7188 - accuracy: 0.4898 - val_loss: 0.7459 - val_accuracy: 0.5408
# Epoch 2/70
# 10/10 [==============================] - 0s 5ms/step - loss: 0.6981 - accuracy: 0.5306 - val_loss: 0.7229 - val_accuracy: 0.5612
# Epoch 3/70
# 10/10 [==============================] - 0s 5ms/step - loss: 0.6788 - accuracy: 0.5714 - val_loss: 0.7023 - val_accuracy: 0.5612
# Epoch 4/70
# 10/10 [==============================] - 0s 5ms/step - loss: 0.6613 - accuracy: 0.5816 - val_loss: 0.6846 - val_accuracy: 0.5510
# Epoch 5/70
# 10/10 [==============================] - 0s 5ms/step - loss: 0.6458 - accuracy: 0.5952 - val_loss: 0.6677 - val_accuracy: 0.5612
# Epoch 6/70
# 10/10 [==============================] - 0s 7ms/step - loss: 0.6300 - accuracy: 0.6224 - val_loss: 0.6522 - val_accuracy: 0.5816
# Epoch 7/70
# 10/10 [==============================] - 0s 7ms/step - loss: 0.6150 - accuracy: 0.6463 - val_loss: 0.6374 - val_accuracy: 0.6020
# Epoch 8/70
# 10/10 [==============================] - 0s 8ms/step - loss: 0.6002 - accuracy: 0.6531 - val_loss: 0.6246 - val_accuracy: 0.6224
# Epoch 9/70
# 10/10 [==============================] - 0s 5ms/step - loss: 0.5865 - accuracy: 0.6667 - val_loss: 0.6124 - val_accuracy: 0.6224
# Epoch 10/70
# 10/10 [==============================] - 0s 5ms/step - loss: 0.5726 - accuracy: 0.6735 - val_loss: 0.6007 - val_accuracy: 0.6224
# Epoch 11/70
# 10/10 [==============================] - 0s 5ms/step - loss: 0.5605 - accuracy: 0.6735 - val_loss: 0.5886 - val_accuracy: 0.6327
# Epoch 12/70
# 10/10 [==============================] - 0s 6ms/step - loss: 0.5485 - accuracy: 0.6837 - val_loss: 0.5770 - val_accuracy: 0.6429
# Epoch 13/70
# 10/10 [==============================] - 0s 5ms/step - loss: 0.5376 - accuracy: 0.6735 - val_loss: 0.5670 - val_accuracy: 0.6531
# Epoch 14/70
# 10/10 [==============================] - 0s 5ms/step - loss: 0.5283 - accuracy: 0.6837 - val_loss: 0.5579 - val_accuracy: 0.6735
# Epoch 15/70
# 10/10 [==============================] - 0s 5ms/step - loss: 0.5194 - accuracy: 0.6973 - val_loss: 0.5493 - val_accuracy: 0.7245
# Epoch 16/70
# 10/10 [==============================] - 0s 5ms/step - loss: 0.5114 - accuracy: 0.7143 - val_loss: 0.5408 - val_accuracy: 0.7347
# Epoch 17/70
# 10/10 [==============================] - 0s 5ms/step - loss: 0.5027 - accuracy: 0.7347 - val_loss: 0.5330 - val_accuracy: 0.7143
# Epoch 18/70
# 10/10 [==============================] - 0s 5ms/step - loss: 0.4952 - accuracy: 0.7449 - val_loss: 0.5260 - val_accuracy: 0.7347
# Epoch 19/70
# 10/10 [==============================] - 0s 7ms/step - loss: 0.4878 - accuracy: 0.7653 - val_loss: 0.5204 - val_accuracy: 0.7551
# Epoch 20/70
# 10/10 [==============================] - 0s 5ms/step - loss: 0.4815 - accuracy: 0.7619 - val_loss: 0.5147 - val_accuracy: 0.7653
# Epoch 21/70
# 10/10 [==============================] - 0s 6ms/step - loss: 0.4745 - accuracy: 0.7619 - val_loss: 0.5091 - val_accuracy: 0.7755
# Epoch 22/70
# 10/10 [==============================] - 0s 5ms/step - loss: 0.4691 - accuracy: 0.7653 - val_loss: 0.5039 - val_accuracy: 0.7959
# Epoch 23/70
# 10/10 [==============================] - 0s 5ms/step - loss: 0.4641 - accuracy: 0.7687 - val_loss: 0.4999 - val_accuracy: 0.8061
# Epoch 24/70
# 10/10 [==============================] - 0s 7ms/step - loss: 0.4591 - accuracy: 0.7687 - val_loss: 0.4966 - val_accuracy: 0.8061
# Epoch 25/70
# 10/10 [==============================] - 0s 7ms/step - loss: 0.4541 - accuracy: 0.7755 - val_loss: 0.4932 - val_accuracy: 0.8163
# Epoch 26/70
# 10/10 [==============================] - 0s 6ms/step - loss: 0.4497 - accuracy: 0.7721 - val_loss: 0.4893 - val_accuracy: 0.8265
# Epoch 27/70
# 10/10 [==============================] - 0s 5ms/step - loss: 0.4451 - accuracy: 0.7721 - val_loss: 0.4872 - val_accuracy: 0.8163
# Epoch 28/70
# 10/10 [==============================] - 0s 7ms/step - loss: 0.4411 - accuracy: 0.7857 - val_loss: 0.4849 - val_accuracy: 0.8163
# Epoch 29/70
# 10/10 [==============================] - 0s 6ms/step - loss: 0.4371 - accuracy: 0.7857 - val_loss: 0.4828 - val_accuracy: 0.8163
# Epoch 30/70
# 10/10 [==============================] - 0s 7ms/step - loss: 0.4336 - accuracy: 0.7891 - val_loss: 0.4809 - val_accuracy: 0.8163
# Epoch 31/70
# 10/10 [==============================] - 0s 5ms/step - loss: 0.4297 - accuracy: 0.7891 - val_loss: 0.4793 - val_accuracy: 0.8061
# Epoch 32/70
# 10/10 [==============================] - 0s 5ms/step - loss: 0.4260 - accuracy: 0.7891 - val_loss: 0.4779 - val_accuracy: 0.7959
# Epoch 33/70
# 10/10 [==============================] - 0s 7ms/step - loss: 0.4225 - accuracy: 0.7891 - val_loss: 0.4760 - val_accuracy: 0.7857
# Epoch 34/70
# 10/10 [==============================] - 0s 5ms/step - loss: 0.4189 - accuracy: 0.7857 - val_loss: 0.4745 - val_accuracy: 0.8061
# Epoch 35/70
# 10/10 [==============================] - 0s 5ms/step - loss: 0.4159 - accuracy: 0.7823 - val_loss: 0.4738 - val_accuracy: 0.8061
# Epoch 36/70
# 10/10 [==============================] - 0s 5ms/step - loss: 0.4125 - accuracy: 0.7857 - val_loss: 0.4729 - val_accuracy: 0.7959
# Epoch 37/70
# 10/10 [==============================] - 0s 5ms/step - loss: 0.4091 - accuracy: 0.7891 - val_loss: 0.4722 - val_accuracy: 0.7959
# Epoch 38/70
# 10/10 [==============================] - 0s 5ms/step - loss: 0.4063 - accuracy: 0.7891 - val_loss: 0.4717 - val_accuracy: 0.7857
# Epoch 39/70
# 10/10 [==============================] - 0s 6ms/step - loss: 0.4032 - accuracy: 0.7993 - val_loss: 0.4710 - val_accuracy: 0.7857
# Epoch 40/70
# 10/10 [==============================] - 0s 5ms/step - loss: 0.4003 - accuracy: 0.7959 - val_loss: 0.4709 - val_accuracy: 0.7857
# Epoch 41/70
# 10/10 [==============================] - 0s 7ms/step - loss: 0.3979 - accuracy: 0.7925 - val_loss: 0.4706 - val_accuracy: 0.7857
# Epoch 42/70
# 10/10 [==============================] - 0s 6ms/step - loss: 0.3949 - accuracy: 0.7925 - val_loss: 0.4710 - val_accuracy: 0.7857
# Epoch 43/70
# 10/10 [==============================] - 0s 5ms/step - loss: 0.3931 - accuracy: 0.7959 - val_loss: 0.4717 - val_accuracy: 0.7959
# Epoch 44/70
# 10/10 [==============================] - 0s 6ms/step - loss: 0.3905 - accuracy: 0.7959 - val_loss: 0.4720 - val_accuracy: 0.7959
# Epoch 45/70
# 10/10 [==============================] - 0s 5ms/step - loss: 0.3885 - accuracy: 0.7959 - val_loss: 0.4727 - val_accuracy: 0.7959
# Epoch 46/70
# 10/10 [==============================] - 0s 5ms/step - loss: 0.3869 - accuracy: 0.8027 - val_loss: 0.4737 - val_accuracy: 0.7857
# Epoch 47/70
# 10/10 [==============================] - 0s 6ms/step - loss: 0.3851 - accuracy: 0.7993 - val_loss: 0.4737 - val_accuracy: 0.7755
# Epoch 48/70
# 10/10 [==============================] - 0s 5ms/step - loss: 0.3832 - accuracy: 0.8061 - val_loss: 0.4739 - val_accuracy: 0.7959
# Epoch 49/70
# 10/10 [==============================] - 0s 7ms/step - loss: 0.3815 - accuracy: 0.8061 - val_loss: 0.4738 - val_accuracy: 0.7959
# Epoch 50/70
# 10/10 [==============================] - 0s 14ms/step - loss: 0.3805 - accuracy: 0.8095 - val_loss: 0.4736 - val_accuracy: 0.7653
# Epoch 51/70
# 10/10 [==============================] - 0s 10ms/step - loss: 0.3782 - accuracy: 0.8095 - val_loss: 0.4744 - val_accuracy: 0.7653
# Epoch 52/70
# 10/10 [==============================] - 0s 10ms/step - loss: 0.3770 - accuracy: 0.8129 - val_loss: 0.4757 - val_accuracy: 0.7755
# Epoch 53/70
# 10/10 [==============================] - 0s 14ms/step - loss: 0.3754 - accuracy: 0.8095 - val_loss: 0.4762 - val_accuracy: 0.7653
# Epoch 54/70
# 10/10 [==============================] - 0s 13ms/step - loss: 0.3741 - accuracy: 0.8095 - val_loss: 0.4767 - val_accuracy: 0.7755
# Epoch 55/70
# 10/10 [==============================] - 0s 10ms/step - loss: 0.3725 - accuracy: 0.8129 - val_loss: 0.4776 - val_accuracy: 0.7653
# Epoch 56/70
# 10/10 [==============================] - 0s 13ms/step - loss: 0.3712 - accuracy: 0.8231 - val_loss: 0.4786 - val_accuracy: 0.7755
# Epoch 57/70
# 10/10 [==============================] - 0s 18ms/step - loss: 0.3698 - accuracy: 0.8231 - val_loss: 0.4792 - val_accuracy: 0.7755
# Epoch 58/70
# 10/10 [==============================] - 0s 12ms/step - loss: 0.3689 - accuracy: 0.8265 - val_loss: 0.4803 - val_accuracy: 0.7755
# Epoch 59/70
# 10/10 [==============================] - 0s 17ms/step - loss: 0.3673 - accuracy: 0.8265 - val_loss: 0.4801 - val_accuracy: 0.7755
# Epoch 60/70
# 10/10 [==============================] - 0s 12ms/step - loss: 0.3661 - accuracy: 0.8299 - val_loss: 0.4808 - val_accuracy: 0.7755
# Epoch 61/70
# 10/10 [==============================] - 0s 13ms/step - loss: 0.3659 - accuracy: 0.8129 - val_loss: 0.4815 - val_accuracy: 0.7755
# Epoch 62/70
# 10/10 [==============================] - 0s 11ms/step - loss: 0.3653 - accuracy: 0.8129 - val_loss: 0.4821 - val_accuracy: 0.7755
# Epoch 63/70
# 10/10 [==============================] - 0s 9ms/step - loss: 0.3640 - accuracy: 0.8129 - val_loss: 0.4825 - val_accuracy: 0.7755
# Epoch 64/70
# 10/10 [==============================] - 0s 11ms/step - loss: 0.3621 - accuracy: 0.8231 - val_loss: 0.4833 - val_accuracy: 0.7755
# Epoch 65/70
# 10/10 [==============================] - 0s 10ms/step - loss: 0.3610 - accuracy: 0.8265 - val_loss: 0.4835 - val_accuracy: 0.7755
# Epoch 66/70
# 10/10 [==============================] - 0s 11ms/step - loss: 0.3592 - accuracy: 0.8333 - val_loss: 0.4848 - val_accuracy: 0.7755
# Epoch 67/70
# 10/10 [==============================] - 0s 11ms/step - loss: 0.3583 - accuracy: 0.8333 - val_loss: 0.4869 - val_accuracy: 0.7857
# Epoch 68/70
# 10/10 [==============================] - 0s 9ms/step - loss: 0.3575 - accuracy: 0.8401 - val_loss: 0.4894 - val_accuracy: 0.7857
# Epoch 69/70
# 10/10 [==============================] - 0s 18ms/step - loss: 0.3570 - accuracy: 0.8401 - val_loss: 0.4899 - val_accuracy: 0.7857
# Epoch 70/70
# 10/10 [==============================] - 0s 10ms/step - loss: 0.3560 - accuracy: 0.8401 - val_loss: 0.4894 - val_accuracy: 0.7857

# %%
# See how your model is doing
plot_history(history, 'accuracy')

# %% [markdown]
# ## Evaluation

# %%
# Make predicitons and evaluate your model
print('Training Scores')

# Define labels for the confusion matrix
labels = ['No Diabetes', 'Diabetes']

# Get training predictions and round them to integers instead of floats
train_preds = np.rint(class_model.predict(X_train))

# Classification Report
print(classification_report(y_train, train_preds))

# Confusion Matrix
conf_mat = confusion_matrix(y_train, train_preds, normalize='true')
heatmap(conf_mat, xticklabels=labels, yticklabels=labels, annot=True)
plt.show()
print('\n')
print('Testing Scores')

# Get testing predictions and round them to integers
test_preds = np.rint(class_model.predict(X_test))

# Classification report
print(classification_report(y_test, test_preds))

# Confusion Matrix
conf_mat = confusion_matrix(y_test, test_preds, normalize='true')
heatmap(conf_mat, xticklabels=labels, yticklabels=labels, annot=True)
plt.show()
# Out:
# Training Scores
#               precision    recall  f1-score   support
#
#            0       0.87      0.90      0.88       196
#            1       0.78      0.72      0.75        98
#
#     accuracy                           0.84       294
#    macro avg       0.82      0.81      0.82       294
# weighted avg       0.84      0.84      0.84       294
# Testing Scores
#               precision    recall  f1-score   support
#
#            0       0.85      0.83      0.84        66
#            1       0.67      0.69      0.68        32
#
#     accuracy                           0.79        98
#    macro avg       0.76      0.76      0.76        98
# weighted avg       0.79      0.79      0.79        98

# %% [markdown]
# # Adding Dropout layers

# %%
# new libraries

from keras.layers import Dropout

# Create your model
n_cols = X_train.shape[1]
class_model2 = Sequential()
class_model2.add(Dense(10000, activation = 'relu', input_dim = X_train.shape[1]))

# add dropout layer
class_model2.add(Dropout(.5)) #. 0.5 say portion of nodes to drop in each epoch

class_model2.add(Dense(1000, activation = 'relu'))

class_model2.add(Dropout(.1))

class_model2.add(Dense(1, activation = 'sigmoid'))

# Compile your model, to use our custom function, set metrics = ['acc']
class_model2.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['acc'])
class_model2.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_6 (Dense)             (None, 10000)             90000
#
#  dropout (Dropout)           (None, 10000)             0
#
#  dense_7 (Dense)             (None, 1000)              10001000
#
#  dropout_1 (Dropout)         (None, 1000)              0
#
#  dense_8 (Dense)             (None, 1)                 1001
#
# =================================================================
# Total params: 10,092,001
# Trainable params: 10,092,001
# Non-trainable params: 0
# _________________________________________________________________

# %%
visualize_nn(class_model2, description=True, figsize=(10,8))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-5a0bf44b7a33> in <module>()
# ----> 1 visualize_nn(class_model2, description=True, figsize=(10,8))
#
# NameError: name 'visualize_nn' is not defined

# %%
# fit your model
history = class_model2.fit(X_train, y_train,
                        validation_data = (X_test, y_test),
                        epochs = 300,verbose=0)

# See how your model is doing
plot_history(history, 'acc')

# %% [markdown]
# # Early Stopping

# %%
from keras.callbacks import EarlyStopping

# Build your model

class_model3 = Sequential()
class_model3.add(Dense(10, activation = 'relu', input_dim = X_train.shape[1]))
class_model3.add(Dense(10, activation = 'relu'))
class_model3.add(Dense(1, activation = 'sigmoid'))

# Compile your model, to use our custom function, set metrics = ['acc']
class_model3.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['acc'])

# %%
# fit your model
history = class_model3.fit(X_train, y_train,
                        validation_data = (X_test, y_test),
                        epochs = 100,
                        callbacks=[EarlyStopping(patience=10)]
                           )

# See how your model is doing
plot_history(history, 'acc')
# Out:
# Epoch 1/100
# 10/10 [==============================] - 1s 24ms/step - loss: 0.9833 - acc: 0.3401 - val_loss: 0.9197 - val_acc: 0.3367
# Epoch 2/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.9154 - acc: 0.3605 - val_loss: 0.8635 - val_acc: 0.3469
# Epoch 3/100
# 10/10 [==============================] - 0s 15ms/step - loss: 0.8591 - acc: 0.3639 - val_loss: 0.8156 - val_acc: 0.3776
# Epoch 4/100
# 10/10 [==============================] - 0s 15ms/step - loss: 0.8095 - acc: 0.3741 - val_loss: 0.7758 - val_acc: 0.3878
# Epoch 5/100
# 10/10 [==============================] - 0s 13ms/step - loss: 0.7677 - acc: 0.3810 - val_loss: 0.7426 - val_acc: 0.3980
# Epoch 6/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.7324 - acc: 0.4456 - val_loss: 0.7145 - val_acc: 0.4898
# Epoch 7/100
# 10/10 [==============================] - 0s 12ms/step - loss: 0.7034 - acc: 0.5068 - val_loss: 0.6917 - val_acc: 0.5510
# Epoch 8/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.6771 - acc: 0.6020 - val_loss: 0.6716 - val_acc: 0.6020
# Epoch 9/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.6561 - acc: 0.6939 - val_loss: 0.6520 - val_acc: 0.6735
# Epoch 10/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.6362 - acc: 0.7347 - val_loss: 0.6360 - val_acc: 0.6939
# Epoch 11/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.6194 - acc: 0.7517 - val_loss: 0.6210 - val_acc: 0.7041
# Epoch 12/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.6038 - acc: 0.7721 - val_loss: 0.6067 - val_acc: 0.7041
# Epoch 13/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.5877 - acc: 0.7687 - val_loss: 0.5931 - val_acc: 0.7347
# Epoch 14/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.5736 - acc: 0.7551 - val_loss: 0.5817 - val_acc: 0.7551
# Epoch 15/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.5600 - acc: 0.7449 - val_loss: 0.5707 - val_acc: 0.7551
# Epoch 16/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.5471 - acc: 0.7483 - val_loss: 0.5604 - val_acc: 0.7449
# Epoch 17/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.5352 - acc: 0.7415 - val_loss: 0.5503 - val_acc: 0.7653
# Epoch 18/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.
# Epoch 73/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.6039 - acc: 0.7755 - val_loss: 0.5943 - val_acc: 0.7959
# Epoch 74/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.6012 - acc: 0.7789 - val_loss: 0.5916 - val_acc: 0.8061
# Epoch 75/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.5991 - acc: 0.7823 - val_loss: 0.5882 - val_acc: 0.8061
# Epoch 76/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.5973 - acc: 0.7823 - val_loss: 0.5849 - val_acc: 0.8163
# Epoch 77/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.5955 - acc: 0.7823 - val_loss: 0.5834 - val_acc: 0.8163
# Epoch 78/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.5932 - acc: 0.7823 - val_loss: 0.5808 - val_acc: 0.8163
# Epoch 79/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.5907 - acc: 0.7789 - val_loss: 0.5795 - val_acc: 0.7959
# Epoch 80/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.5888 - acc: 0.7823 - val_loss: 0.5764 - val_acc: 0.8061
# Epoch 81/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.5863 - acc: 0.7789 - val_loss: 0.5756 - val_acc: 0.8061
# Epoch 82/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.5843 - acc: 0.7823 - val_loss: 0.5737 - val_acc: 0.8061
# Epoch 83/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.5819 - acc: 0.7823 - val_loss: 0.5715 - val_acc: 0.7959
# Epoch 84/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.5801 - acc: 0.7823 - val_loss: 0.5693 - val_acc: 0.7959
# Epoch 85/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.5786 - acc: 0.7823 - val_loss: 0.5682 - val_acc: 0.8163
# Epoch 86/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.5769 - acc: 0.7823 - val_loss: 0.5664 - val_acc: 0.8061
# Epoch 87/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.5765 - acc: 0.7721 - val_loss: 0.5665 - val_acc: 0.8163
# Epoch 88/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.5735 - acc: 0.7789 - val_loss: 0.5638 - val_acc: 0.8163
# Epoch 89/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.5716 - acc: 0.7823 - val_loss: 0.5608 - val_acc: 0.8163
# Epoch 90/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.5704 - acc: 0.7823 - val_loss: 0.5587 - val_acc: 0.8061
# Epoch 91/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.5692 - acc: 0.7823 - val_loss: 0.5588 - val_acc: 0.8163
# Epoch 92/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.5673 - acc: 0.7789 - val_loss: 0.5575 - val_acc: 0.8163
# Epoch 93/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.5659 - acc: 0.7823 - val_loss: 0.5556 - val_acc: 0.8061
# Epoch 94/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.5645 - acc: 0.7789 - val_loss: 0.5541 - val_acc: 0.8061
# Epoch 95/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.5632 - acc: 0.7789 - val_loss: 0.5542 - val_acc: 0.8061
# Epoch 96/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.5622 - acc: 0.7721 - val_loss: 0.5537 - val_acc: 0.8061
# Epoch 97/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.5611 - acc: 0.7687 - val_loss: 0.5512 - val_acc: 0.8061
# Epoch 98/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.5594 - acc: 0.7721 - val_loss: 0.5500 - val_acc: 0.8061
# Epoch 99/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.5581 - acc: 0.7721 - val_loss: 0.5495 - val_acc: 0.7959
# Epoch 100/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.5574 - acc: 0.7687 - val_loss: 0.5484 - val_acc: 0.8061

# %%
plot_history(history, 'acc')

# %% [markdown]
# # Change Batch Size
#
# This is an argument in the `.fit()` method

# %%
from keras import regularizers

# Build your model
class_model5 = Sequential()
class_model5.add(Dense(10, activation = 'relu', 
                       input_dim = X_train.shape[1],
                      ))
class_model5.add(Dense(10, 
                       activation = 'relu',
                      ))
class_model5.add(Dense(1, activation = 'sigmoid'))

# Compile your model, to use our custom function, set metrics = ['acc']
class_model5.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['acc'])

# %%
# fit your model
history = class_model5.fit(X_train, y_train,
                        validation_data = (X_test, y_test),
                        epochs = 100,
                        batch_size=200
                           )

# See how your model is doing
plot_history(history, 'acc')
# Out:
# Epoch 1/100
# 2/2 [==============================] - 1s 128ms/step - loss: 0.9166 - acc: 0.2993 - val_loss: 0.8416 - val_acc: 0.3061
# Epoch 2/100
# 2/2 [==============================] - 0s 21ms/step - loss: 0.9025 - acc: 0.3095 - val_loss: 0.8299 - val_acc: 0.3163
# Epoch 3/100
# 2/2 [==============================] - 0s 21ms/step - loss: 0.8897 - acc: 0.3197 - val_loss: 0.8187 - val_acc: 0.3469
# Epoch 4/100
# 2/2 [==============================] - 0s 21ms/step - loss: 0.
100
# 2/2 [==============================] - 0s 21ms/step - loss: 0.4979 - acc: 0.7755 - val_loss: 0.5429 - val_acc: 0.7041
# Epoch 73/100
# 2/2 [==============================] - 0s 21ms/step - loss: 0.4958 - acc: 0.7755 - val_loss: 0.5417 - val_acc: 0.7041
# Epoch 74/100
# 2/2 [==============================] - 0s 21ms/step - loss: 0.4938 - acc: 0.7755 - val_loss: 0.5405 - val_acc: 0.7041
# Epoch 75/100
# 2/2 [==============================] - 0s 24ms/step - loss: 0.4919 - acc: 0.7755 - val_loss: 0.5395 - val_acc: 0.7143
# Epoch 76/100
# 2/2 [==============================] - 0s 21ms/step - loss: 0.4900 - acc: 0.7721 - val_loss: 0.5384 - val_acc: 0.7143
# Epoch 77/100
# 2/2 [==============================] - 0s 21ms/step - loss: 0.4883 - acc: 0.7721 - val_loss: 0.5374 - val_acc: 0.7041
# Epoch 78/100
# 2/2 [==============================] - 0s 21ms/step - loss: 0.4865 - acc: 0.7755 - val_loss: 0.5365 - val_acc: 0.7143
# Epoch 79/100
# 2/2 [==============================] - 0s 21ms/step - loss: 0.4849 - acc: 0.7721 - val_loss: 0.5356 - val_acc: 0.7143
# Epoch 80/100
# 2/2 [==============================] - 0s 27ms/step - loss: 0.4834 - acc: 0.7721 - val_loss: 0.5347 - val_acc: 0.7143
# Epoch 81/100
# 2/2 [==============================] - 0s 23ms/step - loss: 0.4817 - acc: 0.7687 - val_loss: 0.5339 - val_acc: 0.7143
# Epoch 82/100
# 2/2 [==============================] - 0s 22ms/step - loss: 0.4802 - acc: 0.7721 - val_loss: 0.5331 - val_acc: 0.7143
# Epoch 83/100
# 2/2 [==============================] - 0s 42ms/step - loss: 0.4788 - acc: 0.7721 - val_loss: 0.5323 - val_acc: 0.7143
# Epoch 84/100
# 2/2 [==============================] - 0s 21ms/step - loss: 0.4774 - acc: 0.7721 - val_loss: 0.5317 - val_acc: 0.7245
# Epoch 85/100
# 2/2 [==============================] - 0s 21ms/step - loss: 0.4760 - acc: 0.7687 - val_loss: 0.5312 - val_acc: 0.7245
# Epoch 86/100
# 2/2 [==============================] - 0s 22ms/step - loss: 0.4747 - acc: 0.7653 - val_loss: 0.5307 - val_acc: 0.7245
# Epoch 87/100
# 2/2 [==============================] - 0s 21ms/step - loss: 0.4734 - acc: 0.7653 - val_loss: 0.5302 - val_acc: 0.7245
# Epoch 88/100
# 2/2 [==============================] - 0s 21ms/step - loss: 0.4721 - acc: 0.7687 - val_loss: 0.5296 - val_acc: 0.7245
# Epoch 89/100
# 2/2 [==============================] - 0s 22ms/step - loss: 0.4707 - acc: 0.7687 - val_loss: 0.5291 - val_acc: 0.7245
# Epoch 90/100
# 2/2 [==============================] - 0s 21ms/step - loss: 0.4695 - acc: 0.7687 - val_loss: 0.5285 - val_acc: 0.7245
# Epoch 91/100
# 2/2 [==============================] - 0s 21ms/step - loss: 0.4683 - acc: 0.7687 - val_loss: 0.5279 - val_acc: 0.7245
# Epoch 92/100
# 2/2 [==============================] - 0s 22ms/step - loss: 0.4670 - acc: 0.7721 - val_loss: 0.5274 - val_acc: 0.7245
# Epoch 93/100
# 2/2 [==============================] - 0s 23ms/step - loss: 0.4660 - acc: 0.7755 - val_loss: 0.5268 - val_acc: 0.7245
# Epoch 94/100
# 2/2 [==============================] - 0s 23ms/step - loss: 0.4648 - acc: 0.7755 - val_loss: 0.5262 - val_acc: 0.7347
# Epoch 95/100
# 2/2 [==============================] - 0s 22ms/step - loss: 0.4636 - acc: 0.7721 - val_loss: 0.5257 - val_acc: 0.7347
# Epoch 96/100
# 2/2 [==============================] - 0s 24ms/step - loss: 0.4625 - acc: 0.7721 - val_loss: 0.5251 - val_acc: 0.7347
# Epoch 97/100
# 2/2 [==============================] - 0s 21ms/step - loss: 0.4615 - acc: 0.7721 - val_loss: 0.5246 - val_acc: 0.7347
# Epoch 98/100
# 2/2 [==============================] - 0s 30ms/step - loss: 0.4605 - acc: 0.7721 - val_loss: 0.5241 - val_acc: 0.7347
# Epoch 99/100
# 2/2 [==============================] - 0s 22ms/step - loss: 0.4595 - acc: 0.7619 - val_loss: 0.5236 - val_acc: 0.7347
# Epoch 100/100
# 2/2 [==============================] - 0s 22ms/step - loss: 0.4584 - acc: 0.7619 - val_loss: 0.5232 - val_acc: 0.7347

# %%
plot_history(history, 'acc')

# %% [markdown]
# # Other Options:
# 1. Fewer Nodes
# 2. Just 1 layer instead of 2
# 3. Fewer Epochs
# 4. More nodes, layers, and/or epochs, but also more regularization
# 5. Mixing and matching strategies

# %% [markdown]
# You can find source of this visual function from here :[source](https://towardsdatascience.com/deep-learning-with-python-neural-networks-complete-tutorial-6b53c0b06af0)

# %%
'''
Extract info for each layer in a keras model.
'''
def utils_nn_config(model):
    lst_layers = []
    if "Sequential" in str(model): #-> Sequential doesn't show the input layer
        layer = model.layers[0]
        lst_layers.append({"name":"input", "in":int(layer.input.shape[-1]), "neurons":0, 
                           "out":int(layer.input.shape[-1]), "activation":None,
                           "params":0, "bias":0})
    for layer in model.layers:
        try:
            dic_layer = {"name":layer.name, "in":int(layer.input.shape[-1]), "neurons":layer.units, 
                         "out":int(layer.output.shape[-1]), "activation":layer.get_config()["activation"],
                         "params":layer.get_weights()[0], "bias":layer.get_weights()[1]}
        except:
            dic_layer = {"name":layer.name, "in":int(layer.input.shape[-1]), "neurons":0, 
                         "out":int(layer.output.shape[-1]), "activation":None,
                         "params":0, "bias":0}
        lst_layers.append(dic_layer)
    return lst_layers

def visualize_nn(model, description=False, figsize=(10,8)):
    ## get layers info
    lst_layers = utils_nn_config(model)
    layer_sizes = [layer["out"] for layer in lst_layers]
    
    ## fig setup
    fig = plt.figure(figsize=figsize)
    ax = fig.gca()
    ax.set(title=model.name)
    ax.axis('off')
    left, right, bottom, top = 0.1, 0.9, 0.1, 0.9
    x_space = (right-left) / float(len(layer_sizes)-1)
    y_space = (top-bottom) / float(max(layer_sizes))
    p = 0.025
    
    ## nodes
    for i,n in enumerate(layer_sizes):
        top_on_layer = y_space*(n-1)/2.0 + (top+bottom)/2.0
        layer = lst_layers[i]
        color = "green" if i in [0, len(layer_sizes)-1] else "blue"
        color = "red" if (layer['neurons'] == 0) and (i > 0) else color
        
        ### add description
        if (description is True):
            d = i if i == 0 else i-0.5
            if layer['activation'] is None:
                plt.text(x=left+d*x_space, y=top, fontsize=10, color=color, s=layer["name"].upper())
            else:
                plt.text(x=left+d*x_space, y=top, fontsize=10, color=color, s=layer["name"].upper())
                plt.text(x=left+d*x_space, y=top-p, fontsize=10, color=color, s=layer['activation']+" (")
                plt.text(x=left+d*x_space, y=top-2*p, fontsize=10, color=color, s="Σ"+str(layer['in'])+"[X*w]+b")
                out = " Y"  if i == len(layer_sizes)-1 else " out"
                plt.text(x=left+d*x_space, y=top-3*p, fontsize=10, color=color, s=") = "+str(layer['neurons'])+out)
        
        ### circles
        for m in range(n):
            color = "limegreen" if color == "green" else color
            circle = plt.Circle(xy=(left+i*x_space, top_on_layer-m*y_space-4*p), radius=y_space/4.0, color=color, ec='k', zorder=4)
            ax.add_artist(circle)
            
            ### add text
            if i == 0:
                plt.text(x=left-4*p, y=top_on_layer-m*y_space-4*p, fontsize=10, s=r'$X_{'+str(m+1)+'}$')
            elif i == len(layer_sizes)-1:
                plt.text(x=right+4*p, y=top_on_layer-m*y_space-4*p, fontsize=10, s=r'$y_{'+str(m+1)+'}$')
            else:
                plt.text(x=left+i*x_space+p, y=top_on_layer-m*y_space+(y_space/8.+0.01*y_space)-4*p, fontsize=10, s=r'$H_{'+str(m+1)+'}$')
    
    ## links
    for i, (n_a, n_b) in enumerate(zip(layer_sizes[:-1], layer_sizes[1:])):
        layer = lst_layers[i+1]
        color = "green" if i == len(layer_sizes)-2 else "blue"
        color = "red" if layer['neurons'] == 0 else color
        layer_top_a = y_space*(n_a-1)/2. + (top+bottom)/2. -4*p
        layer_top_b = y_space*(n_b-1)/2. + (top+bottom)/2. -4*p
        for m in range(n_a):
            for o in range(n_b):
                line = plt.Line2D([i*x_space+left, (i+1)*x_space+left], 
                                  [layer_top_a-m*y_space, layer_top_b-o*y_space], 
                                  c=color, alpha=0.5)
                if layer['activation'] is None:
                    if o == m:
                        ax.add_artist(line)
                else:
                    ax.add_artist(line)
    plt.show()
