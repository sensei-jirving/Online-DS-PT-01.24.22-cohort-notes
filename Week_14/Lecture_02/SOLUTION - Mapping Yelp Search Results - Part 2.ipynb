# %% [markdown]
# # Mapping Yelp Search Results - Part 2

# %% [markdown]
# - 04/28/22

# %% [markdown]
# ## Obective

# %% [markdown]
# - For this CodeAlong, we will be working with the Yelp API results from last class.
# - You will load in the .csv.gz of your yelp results and prepare the data for visualization.
# - You will use Plotly Express to create an interactive map with all of the results.

# %% [markdown]
# ## Tools You Will Use
# - Part 1:
#     - Yelp API:
#         - Getting Started:
#             - https://www.yelp.com/developers/documentation/v3/get_started
#
#     - `YelpAPI` python package
#         -  "YelpAPI": https://github.com/gfairchild/yelpapi
# - Part 2:
#
#     - Plotly Express: https://plotly.com/python/getting-started/
#         - With Mapbox API: https://www.mapbox.com/
#         - `px.scatter_mapbox` [Documentation](https://plotly.com/python/scattermapbox/):

# %% [markdown]
# ### Applying Code From
# - [Advanced Transformations with Pandas - Part 1](https://login.codingdojo.com/m/376/12529/88086)
# - [Advanced Transformations with Pandas - Part 2](https://login.codingdojo.com/m/376/12529/88088)

# %% [markdown]
# ### Goal

# %% [markdown]
# - We want to create a map with every restaurant plotted as a scatter plot with detailed information that appears when we hover over a business
# - We will use plotly express's `px.scatter_mapbox` function to accomplish this.
#     - https://plotly.com/python/scattermapbox/
#
#     - We will need a Mapbox API token for some of the options:
#         - https://studio.mapbox.com/

# %% [markdown]
# # Loading Data from Part 1

# %%
## Plotly is not included in your dojo-env
# !pip install plotly
# Out:
# Requirement already satisfied: plotly in /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.8/site-packages (5.6.0)
# Requirement already satisfied: six in /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.8/site-packages (from plotly) (1.15.0)
# Requirement already satisfied: tenacity>=6.2.0 in /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.8/site-packages (from plotly) (8.0.1)

# %%
# Standard Imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import json

## importing plotly 
import plotly.express as px

# %%
## Load in csv.gz
df = pd.read_csv('Data/Burgers_Baltimore.csv.gz')
df
# Out:
#                          id                                    alias  \
# 0    AQ56plNP56TIk3JswtoiMA          abbey-burger-bistro-baltimore-4
# 1    3j6GTI0V2Jshw8e1c3uFoA           the-urban-burger-bar-baltimore
# 2    QHVUhI8JBAcqGj1JufDcHw                  wiley-gunters-baltimore
# 3    DnhKT0A9OIgFdIhzNryJBw          abbey-burger-bistro-baltimore-6
# 4    jvKhto6__tCGfs2N27oWdg  the-outpost-american-tavern-baltimore-2
# ..                      ...                                      ...
# 525  vnOzM6USxuhmuXV_uqg0JA                       filippos-baltimore
# 526  cA-DS-nJlfl7IYre-rjH4Q                  daily-grind-baltimore-8
# 527  x6u_Xd5Zr6skcQsIUiUOng                         jazzys-baltimore
# 528  rtlLrtUn35c9Y2eIcxHT8g         kings-pizza-and-subs-baltimore-2
# 529  rMrTzM9EET0wszOng1eINA                chelles-kitchen-baltimore
#
#                             name  \
# 0            Abbey Burger Bistro
# 1           The Urban Burger Bar
# 2                  Wiley Gunters
# 3            Abbey Burger Bistro
# 4    The Outpost American Tavern
# ..                           ...
# 525                    Filippo's
# 526                  Daily Grind
# 527                      Jazzy's
# 528          King's Pizza & Subs
# 529              Chelles kitchen
#
#                                              image_url  is_closed  \
# 0    https://s3-media4.fl.yelpcdn.com/bphoto/_ZZ4nI...      False
# 1    https://s3-media1.fl.yelpcdn.com/bphoto/mmtgGp...      False
# 2    https://s3-media3.fl.yelpcdn.com/bphoto/Lc-4k9...      False
# 3    https://s3-media3.fl.yelpcdn.com/bphoto/oq4-Iy...      False
# 4    https://s3-media2.fl.yelpcdn.com/bphoto/4bN4vA...      False
# ..                                                 ...        ...
# 525  https://s3-media2.fl.yelpcdn.com/bphoto/NiWpYq...      False
# 526  https://s3-media1.fl.yelpcdn.com/bphoto/jrsOvc...      False
# 527  https://s3-media1.fl.yelpcdn.com/bphoto/NcDv9-...      False
# 528  https://s3-media2.fl.yelpcdn.com/bphoto/9FEdeU...      False
# 529  https://s3-media1.fl.yelpcdn.com/bphoto/M4RMzz...      False
#
#                                                    url  review_count  \
# 0    https://www.yelp.com/biz/abbey-burger-bistro-b...           914
# 1    https://www.yelp.com/biz/the-urban-burger-bar-...            32
# 2    https://www.yelp.com/biz/wiley-gunters-baltimo...           136
# 3    https://www.yelp.com/biz/abbey-burger-bistro-b...           266
# 4    https://www.yelp.com/biz/the-outpost-american-...           183
# ..                                                 ...           ...
# 525  https://www.yelp.com/biz/filippos-baltimore?ad...            51
# 526  https://www.yelp.com/biz/daily-grind-baltimore...           231
# 527  https://www.yelp.com/biz/jazzys-baltimore?adju...             1
# 528  https://www.yelp.com/biz/kings-pizza-and-subs-...            75
# 529  https://www.yelp.com/biz/chelles-kitchen-balti...            11
#
#                                             categories  rating  \
# 0    [{'alias': 'sportsbars', 'title': 'Sports Bars...     4.0
# 1           [{'alias': 'burgers', 'title': 'Burgers'}]     4.5
# 2    [{'alias': 'burgers', 'title': 'Burgers'}, {'a...     4.5
# 3    [{'alias': 'tradamerican', 'title': 'American ...     4.0
# 4    [{'alias': 'bars', 'title': 'Bars'}, {'alias':...     4.5
# ..                                                 ...     ...
# 525  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     3.0
# 526  [{'alias': 'coffee', 'title': 'Coffee & Tea'},...     3.5
# 527  [{'alias': 'burgers', 'title': 'Burgers'}, {'a...     2.0
# 528             [{'alias': 'pizza', 'title': 'Pizza'}]     2.5
# 529  [{'alias': 'hotdogs', 'title': 'Fast Food'}, {...     2.5
#
#                                            coordinates  \
# 0    {'latitude': 39.2771835822848, 'longitude': -7...
# 1       {'latitude': 39.32696, 'longitude': -76.63753}
# 2       {'latitude': 39.27174, 'longitude': -76.60223}
# 3    {'latitude': 39.2822776123555, 'longitude': -7...
# 4    {'latitude': 39.2774761241692, 'longitude': -7...
# ..                                                 ...
# 525     {'latitude': 39.28699, 'longitude': -76.56748}
# 526  {'latitude': 39.2821578979492, 'longitude': -7...
# 527  {'latitude': 39.322087392211, 'longitude': -76...
# 528     {'latitude': 39.33086, 'longitude': -76.63161}
# 529     {'latitude': 39.32332, 'longitude': -76.57185}
#
#                transactions price  \
# 0    ['pickup', 'delivery']    $$
# 1    ['pickup', 'delivery']    $$
# 2    ['pickup', 'delivery']    $$
# 3    ['pickup', 'delivery']    $$
# 4    ['pickup', 'delivery']    $$
# ..                      ...   ...
# 525  ['pickup', 'delivery']     $
# 526            ['delivery']     $
# 527            ['delivery']   NaN
# 528  ['pickup', 'delivery']    $$
# 529  ['pickup', 'delivery']   NaN
#
#                                               location         phone  \
# 0    {'address1': '1041 Marshall St', 'address2': '...  1.443454e+10
# 1    {'address1': '3300 Clipper Mill Rd', 'address2...           NaN
# 2    {'address1': '823 E Fort Ave', 'address2': '',...  1.410637e+10
# 3    {'address1': '811 S Broadway', 'address2': '',...  1.410522e+10
# 4    {'address1': '1032 Riverside Ave', 'address2':...  1.443389e+10
# ..                                                 ...           ...
# 525  {'address1': '418 S Conkling St', 'address2': ...  1.410327e+10
# 526  {'address1': '1720 Thames St', 'address2': '',...  1.410558e+10
# 527  {'address1': '3320 Belair Rd', 'address2': '',...  1.410564e+10
# 528  {'address1': '907 W 36th St', 'address2': None...  1.410889e+10
# 529  {'address1': '3436 Belair Rd', 'address2': '',...  1.410301e+10
#
#       display_phone     distance
# 0    (443) 453-9698  2161.212353
# 1               NaN  4242.702639
# 2    (410) 637-3699  2754.995467
# 3    (410) 522-1428  2009.275703
# 4    (443) 388-9113  2083.657647
# ..              ...          ...
# 525  (410) 327-4550  3607.859236
# 526  (410) 558-0399  2079.005086
# 527  (410) 563-6222  4134.435594
# 528  (410) 889-3663  4382.210159
# 529  (410) 301-4414  4311.772603
#
# [530 rows x 16 columns]

# %% [markdown]
# ## Required Preprocessing

# %% [markdown]
# - 1. We need to get the latitude and longitude for each business as separate columns.
# - We also want to be able to show the restaurants:
#     - name,
#     - price range
#     - address
#     - and if they do delivery or takeout.

# %% [markdown]
# ### Separating Latitude and Longitude

# %%
## use .apply pd.Series to convert a dict to columns
df['coordinates'].apply(pd.Series)
# Out:
#                                                      0
# 0    {'latitude': 39.2771835822848, 'longitude': -7...
# 1       {'latitude': 39.32696, 'longitude': -76.63753}
# 2       {'latitude': 39.27174, 'longitude': -76.60223}
# 3    {'latitude': 39.2822776123555, 'longitude': -7...
# 4    {'latitude': 39.2774761241692, 'longitude': -7...
# ..                                                 ...
# 525     {'latitude': 39.28699, 'longitude': -76.56748}
# 526  {'latitude': 39.2821578979492, 'longitude': -7...
# 527  {'latitude': 39.322087392211, 'longitude': -76...
# 528     {'latitude': 39.33086, 'longitude': -76.63161}
# 529     {'latitude': 39.32332, 'longitude': -76.57185}
#
# [530 rows x 1 columns]

# %% [markdown]
# - Why didn't that work???

# %%
## slice out a single test coordinate
test_coord = df.loc[0,'coordinates']
test_coord
# Out:
# "{'latitude': 39.2771835822848, 'longitude': -76.6129885794452}"

# %% [markdown]
# - Its not a dictionary anymore!!! WTF??
#     - CSV files cant store iterables (lists, dictionaries) so they get converted to strings.

# %% [markdown]
# ### Fixing the String-Dictionaries

# %% [markdown]
# - The json module has another version of load and dump called `json.loads` and `json.dumps`
#     - These are designed to process STRINGS instead of files.
#
# - If we use `json.loads` we can convert our string dictionary into an actual dictionary.

# %%
# ## Use json.loads on the test coordinate
# json.loads(test_coord)

# %% [markdown]
# - JSON requires double quotes!

# %%
## replace single ' with " 
test_coord = test_coord.replace("'",'"')
test_coord
# Out:
# '{"latitude": 39.2771835822848, "longitude": -76.6129885794452}'

# %%
## Use json.loads on the test coordinate, again
json.loads(test_coord)
# Out:
# {'latitude': 39.2771835822848, 'longitude': -76.6129885794452}

# %% [markdown]
# ### Now, how can we apply this same process to the entire column??

# %%
## replace ' with " (entire column)
df['coordinates'] = df['coordinates'].str.replace("'",'"')

## apply json.loads
df['coordinates'] = df['coordinates'].apply(json.loads)

# %%
## slice out a single test coordinate
test_coord = df.loc[0,'coordinates']
type(test_coord)
# Out:
# dict

# %% [markdown]
# ### Using Apply with pd.Series to convert a dictionary column into multiple columns

# %%
## use .apply pd.Series to convert a dict to columns
df['coordinates'].apply(pd.Series)
# Out:
#       latitude  longitude
# 0    39.277184 -76.612989
# 1    39.326960 -76.637530
# 2    39.271740 -76.602230
# 3    39.282278 -76.592749
# 4    39.277476 -76.609180
# ..         ...        ...
# 525  39.286990 -76.567480
# 526  39.282158 -76.591797
# 527  39.322087 -76.573110
# 528  39.330860 -76.631610
# 529  39.323320 -76.571850
#
# [530 rows x 2 columns]

# %%
## Concatenate the 2 new columns and drop the original.
df = pd.concat([df,
                df['coordinates'].apply(pd.Series)],axis=1)
df.drop(columns='coordinates')
df.head()
# Out:
#                        id                                    alias  \
# 0  AQ56plNP56TIk3JswtoiMA          abbey-burger-bistro-baltimore-4
# 1  3j6GTI0V2Jshw8e1c3uFoA           the-urban-burger-bar-baltimore
# 2  QHVUhI8JBAcqGj1JufDcHw                  wiley-gunters-baltimore
# 3  DnhKT0A9OIgFdIhzNryJBw          abbey-burger-bistro-baltimore-6
# 4  jvKhto6__tCGfs2N27oWdg  the-outpost-american-tavern-baltimore-2
#
#                           name  \
# 0          Abbey Burger Bistro
# 1         The Urban Burger Bar
# 2                Wiley Gunters
# 3          Abbey Burger Bistro
# 4  The Outpost American Tavern
#
#                                            image_url  is_closed  \
# 0  https://s3-media4.fl.yelpcdn.com/bphoto/_ZZ4nI...      False
# 1  https://s3-media1.fl.yelpcdn.com/bphoto/mmtgGp...      False
# 2  https://s3-media3.fl.yelpcdn.com/bphoto/Lc-4k9...      False
# 3  https://s3-media3.fl.yelpcdn.com/bphoto/oq4-Iy...      False
# 4  https://s3-media2.fl.yelpcdn.com/bphoto/4bN4vA...      False
#
#                                                  url  review_count  \
# 0  https://www.yelp.com/biz/abbey-burger-bistro-b...           914
# 1  https://www.yelp.com/biz/the-urban-burger-bar-...            32
# 2  https://www.yelp.com/biz/wiley-gunters-baltimo...           136
# 3  https://www.yelp.com/biz/abbey-burger-bistro-b...           266
# 4  https://www.yelp.com/biz/the-outpost-american-...           183
#
#                                           categories  rating  \
# 0  [{'alias': 'sportsbars', 'title': 'Sports Bars...     4.0
# 1         [{'alias': 'burgers', 'title': 'Burgers'}]     4.5
# 2  [{'alias': 'burgers', 'title': 'Burgers'}, {'a...     4.5
# 3  [{'alias': 'tradamerican', 'title': 'American ...     4.0
# 4  [{'alias': 'bars', 'title': 'Bars'}, {'alias':...     4.5
#
#                                          coordinates            transactions  \
# 0  {'latitude': 39.2771835822848, 'longitude': -7...  ['pickup', 'delivery']
# 1     {'latitude': 39.32696, 'longitude': -76.63753}  ['pickup', 'delivery']
# 2     {'latitude': 39.27174, 'longitude': -76.60223}  ['pickup', 'delivery']
# 3  {'latitude': 39.2822776123555, 'longitude': -7...  ['pickup', 'delivery']
# 4  {'latitude': 39.2774761241692, 'longitude': -7...  ['pickup', 'delivery']
#
#   price                                           location         phone  \
# 0    $$  {'address1': '1041 Marshall St', 'address2': '...  1.443454e+10
# 1    $$  {'address1': '3300 Clipper Mill Rd', 'address2...           NaN
# 2    $$  {'address1': '823 E Fort Ave', 'address2': '',...  1.410637e+10
# 3    $$  {'address1': '811 S Broadway', 'address2': '',...  1.410522e+10
# 4    $$  {'address1': '1032 Riverside Ave', 'address2':...  1.443389e+10
#
#     display_phone     distance   latitude  longitude
# 0  (443) 453-9698  2161.212353  39.277184 -76.612989
# 1             NaN  4242.702639  39.326960 -76.637530
# 2  (410) 637-3699  2754.995467  39.271740 -76.602230
# 3  (410) 522-1428  2009.275703  39.282278 -76.592749
# 4  (443) 388-9113  2083.657647  39.277476 -76.609180

# %% [markdown]
# ## Creating a Simple Map

# %% [markdown]
# ### Register for MapBox API

# %%
## Load in mapbox api credentials from .secret
with open('/Users/codingdojo/.secret/mapbox.json') as f:
    login = json.load(f)
login.keys()
# Out:
# dict_keys(['api-key'])

# %% [markdown]
# - Use the plotly express `set_maptbox_acccess_token` function

# %%
## set mapbox token
px.set_mapbox_access_token(login['api-key'])

# %%
## use scatter_mapbox for M.V.P map
px.scatter_mapbox(df, lat='latitude',lon='longitude', mapbox_style='open-street-map')
# Out:
# <div>                            <div id="2dc4f487-dc24-4989-84c4-3ea8ba4ca50c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2dc4f487-dc24-4989-84c4-3ea8ba4ca50c")) {                    Plotly.newPlot(                        "2dc4f487-dc24-4989-84c4-3ea8ba4ca50c",                        [{"hovertemplate":"latitude=%{lat}<br>longitude=%{lon}<extra></extra>","lat":[39.2771835822848,39.32696,39.27174,39.2822776123555,39.2774761241692,39.29588539090596,39.298216,39.30715667,39.3350187678809,39.2867861168311,39.3217276,39.28538,39.29951,39.3016090393066,39.293462,39.295902,39.302825295486,39.29133,39.2871515492791,39.276819,39.2875800984102,39.28814,39.288481314045015,39.29882300693483,39.3259602,39.288553,39.2865982055664,39.2905746,39.29644916572946,39.304130942601,39.28135,39.2762685957044,39.280742,39.2899436853933,39.291471259511,39.3285290707412,39.3114185,39.2898726,39.297203,39.2832841,39.2845959320146,39.2822084,39.282672,39.31951014202046,39.3019803748168,39.330862,39.306794,39.29031,39.288448,39.3299578395486,39.28685,39.2832024,39.28281,39.30839753480792,39.2870995,39.2857429,39.28807,39.285576,39.29021546895015,39.29069,39.2864826376183,39.2845344543457,39.27654,39.3310122069348,39.306,39.28833,39.289519,39.2840965816671,39.2764795638087,39.2764289,39.2889121,39.2723872853157,39.287106243991346,39.29443294321623,39.2768999,39.2819529,39.2995431,39.3314348,39.28214,39.3089608022934,39.31375,39.2850341796875,39.2878409,39.2993096,39.29609,39.2855072021484,39.28564,39.3062583,39.2953689,39.2894744873047,39.28316,39.331877561904,39.291696,39.29205,39.2769315775745,39.2913148,39.29202,39.27301670062398,39.29733,39.2861934616226,39.28237,39.2889294,39.28725,39.3217129089992,39.2717405,39.32772376459962,39.289159,39.286385925645,39.32905,39.2930717,39.2751220151663,39.2819537,39.28353902866672,39.285027860458,39.3262187433177,39.2775711348358,39.29619,39.3308674,39.282112121582,39.2886352,39.2861366271973,39.300042,39.2819708409951,39.283203,39.2987049,39.29466,39.2827339172363,39.28167,39.2819,39.2898529,39.3279914142791,39.2811499,39.2727317810059,39.3285379934512,39.28468,39.3308448791504,39.2718800254781,39.282943,39.28289,39.27303,39.326896,39.2786859808658,39.284521,39.2734724,39.29032,39.30847,39.327062,39.282334,39.2834625244141,39.28128,39.314946584723,39.294392155195,39.30253941451247,39.2820421279263,39.302584,39.2764499,39.3052193,39.31088,39.28161,39.283401121424866,39.275218963623,39.28272,39.2858411929565,39.2681884765625,39.304297,39.3047,39.2784996,39.27276,39.28266359061073,39.271812,39.27902,39.29619,39.29433,39.27093,39.3015706,39.28504892594525,39.281309917441924,39.28731390601493,39.282750670704,39.2778643453029,39.3312912931536,39.28589,39.2830198236714,39.28378692735451,39.30155,39.28914,39.3214001084967,39.27138,39.327825,39.2833953,39.282521,39.295824836586874,39.28594,39.26920460905755,39.27986,39.2903848,39.28454,39.286029,39.286415,39.27412,39.2903848,39.283338,39.3308895,39.297088,39.27718,39.2966270446777,39.291523,39.2870667165587,39.28636,39.2763526,39.28769,39.279137,39.3224101,39.2851,39.307907,39.324284,39.281993127486,39.277408,39.2764296982714,39.282148,39.28481,39.28315,39.2844055,39.29317,39.288145,39.2716569292807,39.282413482666,39.279315147696934,39.2833136855023,39.303409504941,39.30111,39.281193,39.318,39.32162,39.282061,39.3001098632812,39.298081,39.2824450135231,39.2924999,39.276834,39.28402,39.28967,39.3309756,39.2978908941399,39.3047,39.285945,39.282368,39.284758,39.28307,39.284968790949144,39.263636,39.29198,39.286584965829576,39.28991,39.2826128,39.29378948104662,39.27246,39.302711,39.27672775393561,39.29556,39.27706,39.3358827012633,39.2947067,39.2958,39.28754401837799,39.28953,39.3130499,39.2771,39.29592,39.319483,39.284242885897605,39. ...

# %% [markdown]
# ### Adding Hover Data

# %% [markdown]
# - We want to show the restaurants:
#     - name
#     - price range
#     - address
#     - and if they do delivery or takeout.
#
#
# - We can use the `hover_name` and `hover_data` arguments for `px.scatter_mapbox` to add this info!

# %%
df.head(2)
# Out:
#                        id                            alias  \
# 0  AQ56plNP56TIk3JswtoiMA  abbey-burger-bistro-baltimore-4
# 1  3j6GTI0V2Jshw8e1c3uFoA   the-urban-burger-bar-baltimore
#
#                    name                                          image_url  \
# 0   Abbey Burger Bistro  https://s3-media4.fl.yelpcdn.com/bphoto/_ZZ4nI...
# 1  The Urban Burger Bar  https://s3-media1.fl.yelpcdn.com/bphoto/mmtgGp...
#
#    is_closed                                                url  review_count  \
# 0      False  https://www.yelp.com/biz/abbey-burger-bistro-b...           914
# 1      False  https://www.yelp.com/biz/the-urban-burger-bar-...            32
#
#                                           categories  rating  \
# 0  [{'alias': 'sportsbars', 'title': 'Sports Bars...     4.0
# 1         [{'alias': 'burgers', 'title': 'Burgers'}]     4.5
#
#                                          coordinates            transactions  \
# 0  {'latitude': 39.2771835822848, 'longitude': -7...  ['pickup', 'delivery']
# 1     {'latitude': 39.32696, 'longitude': -76.63753}  ['pickup', 'delivery']
#
#   price                                           location         phone  \
# 0    $$  {'address1': '1041 Marshall St', 'address2': '...  1.443454e+10
# 1    $$  {'address1': '3300 Clipper Mill Rd', 'address2...           NaN
#
#     display_phone     distance   latitude  longitude
# 0  (443) 453-9698  2161.212353  39.277184 -76.612989
# 1             NaN  4242.702639  39.326960 -76.637530

# %%
## add hover_name (name) and hover_data for price,rating,location
px.scatter_mapbox(df, lat='latitude',lon='longitude',
                  mapbox_style='open-street-map', hover_name='name',
                 hover_data=['price','rating','location'])
# Out:
# <div>                            <div id="ac246988-13cf-4ded-a59a-59a4aa055b0f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ac246988-13cf-4ded-a59a-59a4aa055b0f")) {                    Plotly.newPlot(                        "ac246988-13cf-4ded-a59a-59a4aa055b0f",                        [{"customdata":[["$$",4.0,"{'address1': '1041 Marshall St', 'address2': '', 'address3': '', 'city': 'Baltimore', 'zip_code': '21230', 'country': 'US', 'state': 'MD', 'display_address': ['1041 Marshall St', 'Baltimore, MD 21230']}"],["$$",4.5,"{'address1': '3300 Clipper Mill Rd', 'address2': '', 'address3': None, 'city': 'Baltimore', 'zip_code': '21211', 'country': 'US', 'state': 'MD', 'display_address': ['3300 Clipper Mill Rd', 'Baltimore, MD 21211']}"],["$$",4.5,"{'address1': '823 E Fort Ave', 'address2': '', 'address3': '', 'city': 'Baltimore', 'zip_code': '21230', 'country': 'US', 'state': 'MD', 'display_address': ['823 E Fort Ave', 'Baltimore, MD 21230']}"],["$$",4.0,"{'address1': '811 S Broadway', 'address2': '', 'address3': '', 'city': 'Baltimore', 'zip_code': '21231', 'country': 'US', 'state': 'MD', 'display_address': ['811 S Broadway', 'Baltimore, MD 21231']}"],["$$",4.5,"{'address1': '1032 Riverside Ave', 'address2': '', 'address3': None, 'city': 'Baltimore', 'zip_code': '21230', 'country': 'US', 'state': 'MD', 'display_address': ['1032 Riverside Ave', 'Baltimore, MD 21230']}"],["$$",3.5,"{'address1': '520 Park Ave', 'address2': '', 'address3': 'Mount Vernon Marketplace', 'city': 'Baltimore', 'zip_code': '21201', 'country': 'US', 'state': 'MD', 'display_address': ['520 Park Ave', 'Mount Vernon Marketplace', 'Baltimore, MD 21201']}"],[null,4.0,"{'address1': '311 W Madison St', 'address2': None, 'address3': '', 'city': 'Baltimore', 'zip_code': '21201', 'country': 'US', 'state': 'MD', 'display_address': ['311 W Madison St', 'Baltimore, MD 21201']}"],[null,5.0,"{'address1': '1501 Bolton St', 'address2': None, 'address3': '', 'city': 'Baltimore', 'zip_code': '21217', 'country': 'US', 'state': 'MD', 'display_address': ['1501 Bolton St', 'Baltimore, MD 21217']}"],["$$",4.0,"{'address1': '3845 Falls Rd', 'address2': '', 'address3': None, 'city': 'Baltimore', 'zip_code': '21211', 'country': 'US', 'state': 'MD', 'display_address': ['3845 Falls Rd', 'Baltimore, MD 21211']}"],["$$",3.5,"{'address1': '400 E Pratt St', 'address2': '', 'address3': '', 'city': 'Baltimore', 'zip_code': '21202', 'country': 'US', 'state': 'MD', 'display_address': ['400 E Pratt St', 'Baltimore, MD 21202']}"],[null,4.0,"{'address1': '301 W 29th St', 'address2': None, 'address3': '', 'city': 'Baltimore', 'zip_code': '21211', 'country': 'US', 'state': 'MD', 'display_address': ['301 W 29th St', 'Baltimore, MD 21211']}"],["$$",4.5,"{'address1': '601 S Clinton St', 'address2': '', 'address3': '', 'city': 'Baltimore', 'zip_code': '21224', 'country': 'US', 'state': 'MD', 'display_address': ['601 S Clinton St', 'Baltimore, MD 21224']}"],[null,5.0,"{'address1': '824 N Calvert St', 'address2': None, 'address3': '', 'city': 'Baltimore', 'zip_code': '21202', 'country': 'US', 'state': 'MD', 'display_address': ['824 N Calvert St', 'Baltimore, MD 21202']}"],["$$",4.0,"{'address1': '223 W Chase St', 'address2': '', 'address3': '', 'city': 'Baltimore', 'zip_code': '21201', 'country': 'US', 'state': 'MD', 'display_address': ['223 W Chase St', 'Baltimore, MD 21201']}"],["$$",4.0,"{'address1': '328 N Charles St', 'address2': '', 'address3': '', 'city': 'Baltimore', 'zip_code': '21201', 'country': 'US', 'state': 'MD', 'display_address': ['328 N Charles St', 'Baltimore, MD 21201']}"],["$$",4.5,"{'address1': '520 Park Ave', 'address2': '', 'address3': '', 'city': 'Baltimore', 'zip_code': '21201', 'country': 'US', 'state': 'MD', 'display_address': ['520 Park  ...

# %% [markdown]
# ### Fixing the Location Column

# %%
## slice out a test address
test_addr = df.loc[0, 'location']
test_addr
# Out:
# "{'address1': '1041 Marshall St', 'address2': '', 'address3': '', 'city': 'Baltimore', 'zip_code': '21230', 'country': 'US', 'state': 'MD', 'display_address': ['1041 Marshall St', 'Baltimore, MD 21230']}"

# %% [markdown]
# > Also a string-dictionary...

# %%
## replace ' with "
df['location'] = df['location'].str.replace("'", '"')
df
# Out:
#                          id                                    alias  \
# 0    AQ56plNP56TIk3JswtoiMA          abbey-burger-bistro-baltimore-4
# 1    3j6GTI0V2Jshw8e1c3uFoA           the-urban-burger-bar-baltimore
# 2    QHVUhI8JBAcqGj1JufDcHw                  wiley-gunters-baltimore
# 3    DnhKT0A9OIgFdIhzNryJBw          abbey-burger-bistro-baltimore-6
# 4    jvKhto6__tCGfs2N27oWdg  the-outpost-american-tavern-baltimore-2
# ..                      ...                                      ...
# 525  vnOzM6USxuhmuXV_uqg0JA                       filippos-baltimore
# 526  cA-DS-nJlfl7IYre-rjH4Q                  daily-grind-baltimore-8
# 527  x6u_Xd5Zr6skcQsIUiUOng                         jazzys-baltimore
# 528  rtlLrtUn35c9Y2eIcxHT8g         kings-pizza-and-subs-baltimore-2
# 529  rMrTzM9EET0wszOng1eINA                chelles-kitchen-baltimore
#
#                             name  \
# 0            Abbey Burger Bistro
# 1           The Urban Burger Bar
# 2                  Wiley Gunters
# 3            Abbey Burger Bistro
# 4    The Outpost American Tavern
# ..                           ...
# 525                    Filippo's
# 526                  Daily Grind
# 527                      Jazzy's
# 528          King's Pizza & Subs
# 529              Chelles kitchen
#
#                                              image_url  is_closed  \
# 0    https://s3-media4.fl.yelpcdn.com/bphoto/_ZZ4nI...      False
# 1    https://s3-media1.fl.yelpcdn.com/bphoto/mmtgGp...      False
# 2    https://s3-media3.fl.yelpcdn.com/bphoto/Lc-4k9...      False
# 3    https://s3-media3.fl.yelpcdn.com/bphoto/oq4-Iy...      False
# 4    https://s3-media2.fl.yelpcdn.com/bphoto/4bN4vA...      False
# ..                                                 ...        ...
# 525  https://s3-media2.fl.yelpcdn.com/bphoto/NiWpYq...      False
# 526  https://s3-media1.fl.yelpcdn.com/bphoto/jrsOvc...      False
# 527  https://s3-media1.fl.yelpcdn.com/bphoto/NcDv9-...      False
# 528  https://s3-media2.fl.yelpcdn.com/bphoto/9FEdeU...      False
# 529  https://s3-media1.fl.yelpcdn.com/bphoto/M4RMzz...      False
#
#                                                    url  review_count  \
# 0    https://www.yelp.com/biz/abbey-burger-bistro-b...           914
# 1    https://www.yelp.com/biz/the-urban-burger-bar-...            32
# 2    https://www.yelp.com/biz/wiley-gunters-baltimo...           136
# 3    https://www.yelp.com/biz/abbey-burger-bistro-b...           266
# 4    https://www.yelp.com/biz/the-outpost-american-...           183
# ..                                                 ...           ...
# 525  https://www.yelp.com/biz/filippos-baltimore?ad...            51
# 526  https://www.yelp.com/biz/daily-grind-baltimore...           231
# 527  https://www.yelp.com/biz/jazzys-baltimore?adju...             1
# 528  https://www.yelp.com/biz/kings-pizza-and-subs-...            75
# 529  https://www.yelp.com/biz/chelles-kitchen-balti...            11
#
#                                             categories  rating  \
# 0    [{'alias': 'sportsbars', 'title': 'Sports Bars...     4.0
# 1           [{'alias': 'burgers', 'title': 'Burgers'}]     4.5
# 2    [{'alias': 'burgers', 'title': 'Burgers'}, {'a...     4.5
# 3    [{'alias': 'tradamerican', 'title': 'American ...     4.0
# 4    [{'alias': 'bars', 'title': 'Bars'}, {'alias':...     4.5
# ..                                                 ...     ...
# 525  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     3.0
# 526  [{'alias': 'coffee', 'title': 'Coffee & Tea'},...     3.5
# 527  [{'alias': 'burgers', 'title': 'Burgers'}, {'a...     2.0
# 528             [{'alias': 'pizza', 'title': 'Pizza'}]     2.5
# 529  [{'alias': 'hotdogs', 'title': 'Fast Food'}, {...     2.5
#
#                                            coordinates  \
# 0    {'latitude': 39.2771835822848, 'longitude': -7...
# 1       {'latitude': 39.32696, 'longitude': -76.63753}
# 2       {'latitude': 39.27174, 'longitude': -76.60223}
# 3    {'latitude': 39.2822776123555, 'longitude': -7...
# 4    {'latitude': 39.2774761241692, 'longitude': -7...
# ..                                                 ...
# 525     {'latitude': 39.28699, 'longitude': -76.56748}
# 526  {'latitude': 39.2821578979492, 'longitude': -7...
# 527  {'latitude': 39.322087392211, 'longitude': -76...
# 528     {'latitude': 39.33086, 'longitude': -76.63161}
# 529     {'latitude': 39.32332, 'longitude': -76.57185}
#
#                transactions price  \
# 0    ['pickup', 'delivery']    $$
# 1    ['pickup', 'delivery']    $$
# 2    ['pickup', 'delivery']    $$
# 3    ['pickup', 'delivery']    $$
# 4    ['pickup', 'delivery']    $$
# ..                      ...   ...
# 525  ['pickup', 'delivery']     $
# 526            ['delivery']     $
# 527            ['delivery']   NaN
# 528  ['pickup', 'delivery']    $$
# 529  ['pickup', 'delivery']   NaN
#
#                                               location         phone  \
# 0    {"address1": "1041 Marshall St", "address2": "...  1.443454e+10
# 1    {"address1": "3300 Clipper Mill Rd", "address2...           NaN
# 2    {"address1": "823 E Fort Ave", "address2": "",...  1.410637e+10
# 3    {"address1": "811 S Broadway", "address2": "",...  1.410522e+10
# 4    {"address1": "1032 Riverside Ave", "address2":...  1.443389e+10
# ..                                                 ...           ...
# 525  {"address1": "418 S Conkling St", "address2": ...  1.410327e+10
# 526  {"address1": "1720 Thames St", "address2": "",...  1.410558e+10
# 527  {"address1": "3320 Belair Rd", "address2": "",...  1.410564e+10
# 528  {"address1": "907 W 36th St", "address2": None...  1.410889e+10
# 529  {"address1": "3436 Belair Rd", "address2": "",...  1.410301e+10
#
#       display_phone     distance   latitude  longitude
# 0    (443) 453-9698  2161.212353  39.277184 -76.612989
# 1               NaN  4242.702639  39.326960 -76.637530
# 2    (410) 637-3699  2754.995467  39.271740 -76.602230
# 3    (410) 522-1428  2009.275703  39.282278 -76.592749
# 4    (443) 388-9113  2083.657647  39.277476 -76.609180
# ..              ...          ...        ...        ...
# 525  (410) 327-4550  3607.859236  39.286990 -76.567480
# 526  (410) 558-0399  2079.005086  39.282158 -76.591797
# 527  (410) 563-6222  4134.435594  39.322087 -76.573110
# 528  (410) 889-3663  4382.210159  39.330860 -76.631610
# 529  (410) 301-4414  4311.772603  39.323320 -76.571850
#
# [530 rows x 18 columns]

# %%
# ## apply json.loads
# df['location'] = df['location'].apply(json.loads)
# df

# %% [markdown]
# > Ruh roh....
#
# - Hmm, let's slice out a test_address again and let's write a function to accomplish this instead.
#     - We can use try and except in our function to get around the errors.

# %% [markdown]
# ### Fixing Addresses - with a custom function

# %%
## slice out test address 
test_addr = df.loc[0, 'location']
test_addr
# Out:
# '{"address1": "1041 Marshall St", "address2": "", "address3": "", "city": "Baltimore", "zip_code": "21230", "country": "US", "state": "MD", "display_address": ["1041 Marshall St", "Baltimore, MD 21230"]}'

# %%
## write a function to just run json.loads on the address
def fix_address(test_addr):
    try:
        return json.loads(test_addr)
    except:
        return "ERROR"

# %%
## test applying our function
df['location'].apply(fix_address)
# Out:
# 0      {'address1': '1041 Marshall St', 'address2': '...
# 1                                                  ERROR
# 2      {'address1': '823 E Fort Ave', 'address2': '',...
# 3      {'address1': '811 S Broadway', 'address2': '',...
# 4                                                  ERROR
#                              ...
# 525    {'address1': '418 S Conkling St', 'address2': ...
# 526    {'address1': '1720 Thames St', 'address2': '',...
# 527    {'address1': '3320 Belair Rd', 'address2': '',...
# 528                                                ERROR
# 529                                                ERROR
# Name: location, Length: 530, dtype: object

# %% [markdown]
# - It worked! Now let's save this as a new column (display_location),
# and then let's investigate the businesses that had an "ERROR".

# %%
### save a new display_location column using our function
df['display_location'] = df['location'].apply(fix_address)

# %%
## filter for businesses with display_location == "ERROR"
df[df['display_location'] == 'ERROR']
# Out:
#                          id  \
# 1    3j6GTI0V2Jshw8e1c3uFoA
# 4    jvKhto6__tCGfs2N27oWdg
# 6    LkCSwCV-WX2eCnv5RUM3Kw
# 7    5CM8nuqd0od68GqQ-UGicQ
# 8    GOvVNYe2DwjGzwdVJIKw1Q
# ..                      ...
# 514  p8_yO34vsydnG-AgoIyIMA
# 521  4QrEtrKk8A2o1CclzKcKqg
# 524  gXQL3Zmlv0aXzjhYPRt5tg
# 528  rtlLrtUn35c9Y2eIcxHT8g
# 529  rMrTzM9EET0wszOng1eINA
#
#                                                  alias  \
# 1                       the-urban-burger-bar-baltimore
# 4              the-outpost-american-tavern-baltimore-2
# 6    311-west-madison-ave-craft-beer-and-wine-resta...
# 7                                cookhouse-baltimore-2
# 8                      wicked-sisters-tavern-baltimore
# ..                                                 ...
# 514                    canton-pizza-and-deli-baltimore
# 521                   ny-chicken-and-grill-baltimore-2
# 524                             mcdonalds-baltimore-57
# 528                   kings-pizza-and-subs-baltimore-2
# 529                          chelles-kitchen-baltimore
#
#                                                   name  \
# 1                                 The Urban Burger Bar
# 4                          The Outpost American Tavern
# 6    311 West Madison Ave Craft Beer & Wine Restaurant
# 7                                            CookHouse
# 8                                Wicked Sisters Tavern
# ..                                                 ...
# 514                                Canton Pizza & Deli
# 521                                 NY Chicken & Grill
# 524                                         McDonald's
# 528                                King's Pizza & Subs
# 529                                    Chelles kitchen
#
#                                              image_url  is_closed  \
# 1    https://s3-media1.fl.yelpcdn.com/bphoto/mmtgGp...      False
# 4    https://s3-media2.fl.yelpcdn.com/bphoto/4bN4vA...      False
# 6    https://s3-media1.fl.yelpcdn.com/bphoto/g7er6A...      False
# 7    https://s3-media2.fl.yelpcdn.com/bphoto/N-2JWj...      False
# 8    https://s3-media2.fl.yelpcdn.com/bphoto/XdSbMU...      False
# ..                                                 ...        ...
# 514  https://s3-media1.fl.yelpcdn.com/bphoto/WO2KWf...      False
# 521                                                NaN      False
# 524  https://s3-media2.fl.yelpcdn.com/bphoto/VAqcvo...      False
# 528  https://s3-media2.fl.yelpcdn.com/bphoto/9FEdeU...      False
# 529  https://s3-media1.fl.yelpcdn.com/bphoto/M4RMzz...      False
#
#                                                    url  review_count  \
# 1    https://www.yelp.com/biz/the-urban-burger-bar-...            32
# 4    https://www.yelp.com/biz/the-outpost-american-...           183
# 6    https://www.yelp.com/biz/311-west-madison-ave-...             6
# 7    https://www.yelp.com/biz/cookhouse-baltimore-2...            20
# 8    https://www.yelp.com/biz/wicked-sisters-tavern...           572
# ..                                                 ...           ...
# 514  https://www.yelp.com/biz/canton-pizza-and-deli...            83
# 521  https://www.yelp.com/biz/ny-chicken-and-grill-...             2
# 524  https://www.yelp.com/biz/mcdonalds-baltimore-5...             6
# 528  https://www.yelp.com/biz/kings-pizza-and-subs-...            75
# 529  https://www.yelp.com/biz/chelles-kitchen-balti...            11
#
#                                             categories  rating  \
# 1           [{'alias': 'burgers', 'title': 'Burgers'}]     4.5
# 4    [{'alias': 'bars', 'title': 'Bars'}, {'alias':...     4.5
# 6    [{'alias': 'bars', 'title': 'Bars'}, {'alias':...     4.0
# 7    [{'alias': 'newamerican', 'title': 'American (...     5.0
# 8    [{'alias': 'tradamerican', 'title': 'American ...     4.0
# ..                                                 ...     ...
# 514             [{'alias': 'pizza', 'title': 'Pizza'}]     2.5
# 521  [{'alias': 'hotdogs', 'title': 'Fast Food'}, {...     2.0
# 524  [{'alias': 'coffee', 'title': 'Coffee & Tea'},...     1.5
# 528             [{'alias': 'pizza', 'title': 'Pizza'}]     2.5
# 529  [{'alias': 'hotdogs', 'title': 'Fast Food'}, {...     2.5
#
#                                            coordinates  \
# 1       {'latitude': 39.32696, 'longitude': -76.63753}
# 4    {'latitude': 39.2774761241692, 'longitude': -7...
# 6     {'latitude': 39.298216, 'longitude': -76.620656}
# 7    {'latitude': 39.30715667, 'longitude': -76.625...
# 8    {'latitude': 39.3350187678809, 'longitude': -7...
# ..                                                 ...
# 514  {'latitude': 39.2806129455566, 'longitude': -7...
# 521     {'latitude': 39.28481, 'longitude': -76.65004}
# 524  {'latitude': 39.3093679758871, 'longitude': -7...
# 528     {'latitude': 39.33086, 'longitude': -76.63161}
# 529     {'latitude': 39.32332, 'longitude': -76.57185}
#
#                transactions price  \
# 1    ['pickup', 'delivery']    $$
# 4    ['pickup', 'delivery']    $$
# 6    ['pickup', 'delivery']   NaN
# 7    ['pickup', 'delivery']   NaN
# 8    ['pickup', 'delivery']    $$
# ..                      ...   ...
# 514  ['pickup', 'delivery']     $
# 521  ['pickup', 'delivery']   NaN
# 524            ['delivery']     $
# 528  ['pickup', 'delivery']    $$
# 529  ['pickup', 'delivery']   NaN
#
#                                               location         phone  \
# 1    {"address1": "3300 Clipper Mill Rd", "address2...           NaN
# 4    {"address1": "1032 Riverside Ave", "address2":...  1.443389e+10
# 6    {"address1": "311 W Madison St", "address2": N...  1.443939e+10
# 7    {"address1": "1501 Bolton St", "address2": Non...  1.410226e+10
# 8    {"address1": "3845 Falls Rd", "address2": "", ...  1.410878e+10
# ..                                                 ...           ...
# 514  {"address1": "3300 O"Donnell St", "address2": ...  1.410564e+10
# 521  {"address1": "2101 W Pratt St", "address2": ""...  1.443709e+10
# 524  {"address1": "4526 Erdman Ave", "address2": No...  1.410484e+10
# 528  {"address1": "907 W 36th St", "address2": None...  1.410889e+10
# 529  {"address1": "3436 Belair Rd", "address2": "",...  1.410301e+10
#
#       display_phone     distance   latitude  longitude display_location
# 1               NaN  4242.702639  39.326960 -76.637530            ERROR
# 4    (443) 388-9113  2083.657647  39.277476 -76.609180            ERROR
# 6    (443) 938-9109  1141.160510  39.298216 -76.620656            ERROR
# 7    (410) 225-9964  1990.078956  39.307157 -76.625848            ERROR
# 8    (410) 878-0884  4974.443762  39.335019 -76.636358            ERROR
# ..              ...          ...        ...        ...              ...
# 514  (410) 563-7777  3716.916969  39.280613 -76.569435            ERROR
# 521  (443) 708-5338  3860.731194  39.284810 -76.650040            ERROR
# 524  (410) 483-9723  4193.333190  39.309368 -76.562009            ERROR
# 528  (410) 889-3663  4382.210159  39.330860 -76.631610            ERROR
# 529  (410) 301-4414  4311.772603  39.323320 -76.571850            ERROR
#
# [212 rows x 19 columns]

# %%
## slice out a new test address and inspect
test_addr = df.loc[437, 'location']
test_addr
# Out:
# '{"address1": "2036 Eastern Ave", "address2": "", "address3": None, "city": "Baltimore", "zip_code": "21231", "country": "US", "state": "MD", "display_address": ["2036 Eastern Ave", "Baltimore, MD 21231"]}'

# %% [markdown]
# > After some more investigation, we would find a few issues with these "ERROR" rows.
# 1. They contained None.
# 2. They contained an apostrophe in the name.
# 3. ...?

# %% [markdown]
# ### Possible Fixes (if we care to/have the time)

# %% [markdown]
# - Use Regular Expressions to find an fix the display addresses with "'" in them
# - Use string split to split on the word display address.
#     - Then use string methods to clean up

# %% [markdown]
# ### Moving Forward without those rows (for now)

# %%
## remove and rows where display_location == 'ERROR'
df = df.loc[df['display_location'] != 'ERROR']
df
# Out:
#                          id                                alias  \
# 0    AQ56plNP56TIk3JswtoiMA      abbey-burger-bistro-baltimore-4
# 2    QHVUhI8JBAcqGj1JufDcHw              wiley-gunters-baltimore
# 3    DnhKT0A9OIgFdIhzNryJBw      abbey-burger-bistro-baltimore-6
# 5    S3keMV3sQjujV-oA-Ymxog           between-2-buns-baltimore-2
# 9    L_cDwPh8kuxkEP-VXjJF-A                shake-shack-baltimore
# ..                      ...                                  ...
# 522  sJOcdfLvAnnBy6Vo0ylANQ              chris-seafood-baltimore
# 523  dWI0jCoOqjge9VQTIad-Ww  york-pizza-subs-and-wings-baltimore
# 525  vnOzM6USxuhmuXV_uqg0JA                   filippos-baltimore
# 526  cA-DS-nJlfl7IYre-rjH4Q              daily-grind-baltimore-8
# 527  x6u_Xd5Zr6skcQsIUiUOng                     jazzys-baltimore
#
#                           name  \
# 0          Abbey Burger Bistro
# 2                Wiley Gunters
# 3          Abbey Burger Bistro
# 5               Between 2 Buns
# 9                  Shake Shack
# ..                         ...
# 522             Chris' Seafood
# 523  York Pizza Subs and Wings
# 525                  Filippo's
# 526                Daily Grind
# 527                    Jazzy's
#
#                                              image_url  is_closed  \
# 0    https://s3-media4.fl.yelpcdn.com/bphoto/_ZZ4nI...      False
# 2    https://s3-media3.fl.yelpcdn.com/bphoto/Lc-4k9...      False
# 3    https://s3-media3.fl.yelpcdn.com/bphoto/oq4-Iy...      False
# 5    https://s3-media1.fl.yelpcdn.com/bphoto/wfTqwH...      False
# 9    https://s3-media2.fl.yelpcdn.com/bphoto/cORtQV...      False
# ..                                                 ...        ...
# 522  https://s3-media1.fl.yelpcdn.com/bphoto/RpSPa-...      False
# 523  https://s3-media4.fl.yelpcdn.com/bphoto/Ay3jyi...      False
# 525  https://s3-media2.fl.yelpcdn.com/bphoto/NiWpYq...      False
# 526  https://s3-media1.fl.yelpcdn.com/bphoto/jrsOvc...      False
# 527  https://s3-media1.fl.yelpcdn.com/bphoto/NcDv9-...      False
#
#                                                    url  review_count  \
# 0    https://www.yelp.com/biz/abbey-burger-bistro-b...           914
# 2    https://www.yelp.com/biz/wiley-gunters-baltimo...           136
# 3    https://www.yelp.com/biz/abbey-burger-bistro-b...           266
# 5    https://www.yelp.com/biz/between-2-buns-baltim...           162
# 9    https://www.yelp.com/biz/shake-shack-baltimore...           518
# ..                                                 ...           ...
# 522  https://www.yelp.com/biz/chris-seafood-baltimo...            54
# 523  https://www.yelp.com/biz/york-pizza-subs-and-w...            49
# 525  https://www.yelp.com/biz/filippos-baltimore?ad...            51
# 526  https://www.yelp.com/biz/daily-grind-baltimore...           231
# 527  https://www.yelp.com/biz/jazzys-baltimore?adju...             1
#
#                                             categories  rating  \
# 0    [{'alias': 'sportsbars', 'title': 'Sports Bars...     4.0
# 2    [{'alias': 'burgers', 'title': 'Burgers'}, {'a...     4.5
# 3    [{'alias': 'tradamerican', 'title': 'American ...     4.0
# 5    [{'alias': 'burgers', 'title': 'Burgers'}, {'a...     3.5
# 9    [{'alias': 'newamerican', 'title': 'American (...     3.5
# ..                                                 ...     ...
# 522         [{'alias': 'seafood', 'title': 'Seafood'}]     3.5
# 523             [{'alias': 'pizza', 'title': 'Pizza'}]     2.5
# 525  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     3.0
# 526  [{'alias': 'coffee', 'title': 'Coffee & Tea'},...     3.5
# 527  [{'alias': 'burgers', 'title': 'Burgers'}, {'a...     2.0
#
#                                            coordinates  \
# 0    {'latitude': 39.2771835822848, 'longitude': -7...
# 2       {'latitude': 39.27174, 'longitude': -76.60223}
# 3    {'latitude': 39.2822776123555, 'longitude': -7...
# 5    {'latitude': 39.29588539090596, 'longitude': -...
# 9    {'latitude': 39.2867861168311, 'longitude': -7...
# ..                                                 ...
# 522  {'latitude': 39.2828178405762, 'longitude': -7...
# 523  {'latitude': 39.3298530578613, 'longitude': -7...
# 525     {'latitude': 39.28699, 'longitude': -76.56748}
# 526  {'latitude': 39.2821578979492, 'longitude': -7...
# 527  {'latitude': 39.322087392211, 'longitude': -76...
#
#                transactions price  \
# 0    ['pickup', 'delivery']    $$
# 2    ['pickup', 'delivery']    $$
# 3    ['pickup', 'delivery']    $$
# 5              ['delivery']    $$
# 9    ['pickup', 'delivery']    $$
# ..                      ...   ...
# 522  ['pickup', 'delivery']    $$
# 523  ['pickup', 'delivery']     $
# 525  ['pickup', 'delivery']     $
# 526            ['delivery']     $
# 527            ['delivery']   NaN
#
#                                               location         phone  \
# 0    {"address1": "1041 Marshall St", "address2": "...  1.443454e+10
# 2    {"address1": "823 E Fort Ave", "address2": "",...  1.410637e+10
# 3    {"address1": "811 S Broadway", "address2": "",...  1.410522e+10
# 5    {"address1": "520 Park Ave", "address2": "", "...  1.667303e+10
# 9    {"address1": "400 E Pratt St", "address2": "",...  1.443973e+10
# ..                                                 ...           ...
# 522  {"address1": "801 S Montford Ave", "address2":...  1.410675e+10
# 523  {"address1": "3401 Greenmount Ave", "address2"...  1.410236e+10
# 525  {"address1": "418 S Conkling St", "address2": ...  1.410327e+10
# 526  {"address1": "1720 Thames St", "address2": "",...  1.410558e+10
# 527  {"address1": "3320 Belair Rd", "address2": "",...  1.410564e+10
#
#       display_phone     distance   latitude  longitude  \
# 0    (443) 453-9698  2161.212353  39.277184 -76.612989
# 2    (410) 637-3699  2754.995467  39.271740 -76.602230
# 3    (410) 522-1428  2009.275703  39.282278 -76.592749
# 5    (667) 303-3273   931.324381  39.295885 -76.618482
# 9    (443) 973-3630  1059.381610  39.286786 -76.609732
# ..              ...          ...        ...        ...
# 522  (410) 675-0117  2628.043743  39.282818 -76.582420
# 523  (410) 235-6290  3743.767034  39.329853 -76.609146
# 525  (410) 327-4550  3607.859236  39.286990 -76.567480
# 526  (410) 558-0399  2079.005086  39.282158 -76.591797
# 527  (410) 563-6222  4134.435594  39.322087 -76.573110
#
#                                       display_location
# 0    {'address1': '1041 Marshall St', 'address2': '...
# 2    {'address1': '823 E Fort Ave', 'address2': '',...
# 3    {'address1': '811 S Broadway', 'address2': '',...
# 5    {'address1': '520 Park Ave', 'address2': '', '...
# 9    {'address1': '400 E Pratt St', 'address2': '',...
# ..                                                 ...
# 522  {'address1': '801 S Montford Ave', 'address2':...
# 523  {'address1': '3401 Greenmount Ave', 'address2'...
# 525  {'address1': '418 S Conkling St', 'address2': ...
# 526  {'address1': '1720 Thames St', 'address2': '',...
# 527  {'address1': '3320 Belair Rd', 'address2': '',...
#
# [318 rows x 19 columns]

# %% [markdown]
# - We want the "display_address" key from the "display_location" dictionaries.
# - We could use a .apply and a lamda to slice out the desired key.

# %%
## use apply and lambda to slice correct key
df['display_address'] = df['display_location'].apply(lambda x: x['display_address'])
df
# Out:
# /var/folders/rf/vw4r41jd7vd95x1w0dth7v9h0000gp/T/ipykernel_32780/1758132525.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                          id                                alias  \
# 0    AQ56plNP56TIk3JswtoiMA      abbey-burger-bistro-baltimore-4
# 2    QHVUhI8JBAcqGj1JufDcHw              wiley-gunters-baltimore
# 3    DnhKT0A9OIgFdIhzNryJBw      abbey-burger-bistro-baltimore-6
# 5    S3keMV3sQjujV-oA-Ymxog           between-2-buns-baltimore-2
# 9    L_cDwPh8kuxkEP-VXjJF-A                shake-shack-baltimore
# ..                      ...                                  ...
# 522  sJOcdfLvAnnBy6Vo0ylANQ              chris-seafood-baltimore
# 523  dWI0jCoOqjge9VQTIad-Ww  york-pizza-subs-and-wings-baltimore
# 525  vnOzM6USxuhmuXV_uqg0JA                   filippos-baltimore
# 526  cA-DS-nJlfl7IYre-rjH4Q              daily-grind-baltimore-8
# 527  x6u_Xd5Zr6skcQsIUiUOng                     jazzys-baltimore
#
#                           name  \
# 0          Abbey Burger Bistro
# 2                Wiley Gunters
# 3          Abbey Burger Bistro
# 5               Between 2 Buns
# 9                  Shake Shack
# ..                         ...
# 522             Chris' Seafood
# 523  York Pizza Subs and Wings
# 525                  Filippo's
# 526                Daily Grind
# 527                    Jazzy's
#
#                                              image_url  is_closed  \
# 0    https://s3-media4.fl.yelpcdn.com/bphoto/_ZZ4nI...      False
# 2    https://s3-media3.fl.yelpcdn.com/bphoto/Lc-4k9...      False
# 3    https://s3-media3.fl.yelpcdn.com/bphoto/oq4-Iy...      False
# 5    https://s3-media1.fl.yelpcdn.com/bphoto/wfTqwH...      False
# 9    https://s3-media2.fl.yelpcdn.com/bphoto/cORtQV...      False
# ..                                                 ...        ...
# 522  https://s3-media1.fl.yelpcdn.com/bphoto/RpSPa-...      False
# 523  https://s3-media4.fl.yelpcdn.com/bphoto/Ay3jyi...      False
# 525  https://s3-media2.fl.yelpcdn.com/bphoto/NiWpYq...      False
# 526  https://s3-media1.fl.yelpcdn.com/bphoto/jrsOvc...      False
# 527  https://s3-media1.fl.yelpcdn.com/bphoto/NcDv9-...      False
#
#                                                    url  review_count  \
# 0    https://www.yelp.com/biz/abbey-burger-bistro-b...           914
# 2    https://www.yelp.com/biz/wiley-gunters-baltimo...           136
# 3    https://www.yelp.com/biz/abbey-burger-bistro-b...           266
# 5    https://www.yelp.com/biz/between-2-buns-baltim...           162
# 9    https://www.yelp.com/biz/shake-shack-baltimore...           518
# ..                                                 ...           ...
# 522  https://www.yelp.com/biz/chris-seafood-baltimo...            54
# 523  https://www.yelp.com/biz/york-pizza-subs-and-w...            49
# 525  https://www.yelp.com/biz/filippos-baltimore?ad...            51
# 526  https://www.yelp.com/biz/daily-grind-baltimore...           231
# 527  https://www.yelp.com/biz/jazzys-baltimore?adju...             1
#
#                                             categories  rating  \
# 0    [{'alias': 'sportsbars', 'title': 'Sports Bars...     4.0
# 2    [{'alias': 'burgers', 'title': 'Burgers'}, {'a...     4.5
# 3    [{'alias': 'tradamerican', 'title': 'American ...     4.0
# 5    [{'alias': 'burgers', 'title': 'Burgers'}, {'a...     3.5
# 9    [{'alias': 'newamerican', 'title': 'American (...     3.5
# ..                                                 ...     ...
# 522         [{'alias': 'seafood', 'title': 'Seafood'}]     3.5
# 523             [{'alias': 'pizza', 'title': 'Pizza'}]     2.5
# 525  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     3.0
# 526  [{'alias': 'coffee', 'title': 'Coffee & Tea'},...     3.5
# 527  [{'alias': 'burgers', 'title': 'Burgers'}, {'a...     2.0
#
#                                            coordinates  \
# 0    {'latitude': 39.2771835822848, 'longitude': -7...
# 2       {'latitude': 39.27174, 'longitude': -76.60223}
# 3    {'latitude': 39.2822776123555, 'longitude': -7...
# 5    {'latitude': 39.29588539090596, 'longitude': -...
# 9    {'latitude': 39.2867861168311, 'longitude': -7...
# ..                                                 ...
# 522  {'latitude': 39.2828178405762, 'longitude': -7...
# 523  {'latitude': 39.3298530578613, 'longitude': -7...
# 525     {'latitude': 39.28699, 'longitude': -76.56748}
# 526  {'latitude': 39.2821578979492, 'longitude': -7...
# 527  {'latitude': 39.322087392211, 'longitude': -76...
#
#                transactions price  \
# 0    ['pickup', 'delivery']    $$
# 2    ['pickup', 'delivery']    $$
# 3    ['pickup', 'delivery']    $$
# 5              ['delivery']    $$
# 9    ['pickup', 'delivery']    $$
# ..                      ...   ...
# 522  ['pickup', 'delivery']    $$
# 523  ['pickup', 'delivery']     $
# 525  ['pickup', 'delivery']     $
# 526            ['delivery']     $
# 527            ['delivery']   NaN
#
#                                               location         phone  \
# 0    {"address1": "1041 Marshall St", "address2": "...  1.443454e+10
# 2    {"address1": "823 E Fort Ave", "address2": "",...  1.410637e+10
# 3    {"address1": "811 S Broadway", "address2": "",...  1.410522e+10
# 5    {"address1": "520 Park Ave", "address2": "", "...  1.667303e+10
# 9    {"address1": "400 E Pratt St", "address2": "",...  1.443973e+10
# ..                                                 ...           ...
# 522  {"address1": "801 S Montford Ave", "address2":...  1.410675e+10
# 523  {"address1": "3401 Greenmount Ave", "address2"...  1.410236e+10
# 525  {"address1": "418 S Conkling St", "address2": ...  1.410327e+10
# 526  {"address1": "1720 Thames St", "address2": "",...  1.410558e+10
# 527  {"address1": "3320 Belair Rd", "address2": "",...  1.410564e+10
#
#       display_phone     distance   latitude  longitude  \
# 0    (443) 453-9698  2161.212353  39.277184 -76.612989
# 2    (410) 637-3699  2754.995467  39.271740 -76.602230
# 3    (410) 522-1428  2009.275703  39.282278 -76.592749
# 5    (667) 303-3273   931.324381  39.295885 -76.618482
# 9    (443) 973-3630  1059.381610  39.286786 -76.609732
# ..              ...          ...        ...        ...
# 522  (410) 675-0117  2628.043743  39.282818 -76.582420
# 523  (410) 235-6290  3743.767034  39.329853 -76.609146
# 525  (410) 327-4550  3607.859236  39.286990 -76.567480
# 526  (410) 558-0399  2079.005086  39.282158 -76.591797
# 527  (410) 563-6222  4134.435594  39.322087 -76.573110
#
#                                       display_location  \
# 0    {'address1': '1041 Marshall St', 'address2': '...
# 2    {'address1': '823 E Fort Ave', 'address2': '',...
# 3    {'address1': '811 S Broadway', 'address2': '',...
# 5    {'address1': '520 Park Ave', 'address2': '', '...
# 9    {'address1': '400 E Pratt St', 'address2': '',...
# ..                                                 ...
# 522  {'address1': '801 S Montford Ave', 'address2':...
# 523  {'address1': '3401 Greenmount Ave', 'address2'...
# 525  {'address1': '418 S Conkling St', 'address2': ...
# 526  {'address1': '1720 Thames St', 'address2': '',...
# 527  {'address1': '3320 Belair Rd', 'address2': '',...
#
#                                        display_address
# 0              [1041 Marshall St, Baltimore, MD 21230]
# 2                [823 E Fort Ave, Baltimore, MD 21230]
# 3                [811 S Broadway, Baltimore, MD 21231]
# 5    [520 Park Ave, Mount Vernon Marketplace, Balti...
# 9                [400 E Pratt St, Baltimore, MD 21202]
# ..                                                 ...
# 522          [801 S Montford Ave, Baltimore, MD 21224]
# 523         [3401 Greenmount Ave, Baltimore, MD 21218]
# 525           [418 S Conkling St, Baltimore, MD 21224]
# 526              [1720 Thames St, Baltimore, MD 21231]
# 527              [3320 Belair Rd, Baltimore, MD 21213]
#
# [318 rows x 20 columns]

# %% [markdown]
# - Almost done! We want to convert display_address to a string instead a list of strings.
# - We can use the string method .join to do so!

# %%
## slice out a test_address
test_addr = df.loc[527, 'display_address']
test_addr
# Out:
# ['3320 Belair Rd', 'Baltimore, MD 21213']

# %%
## test using .join with a "\n"
'\n'.join(test_addr)
# Out:
# '3320 Belair Rd\nBaltimore, MD 21213'

# %%
## apply the join to every row with a lambda
df['Address'] = df['display_address'].apply(lambda x: '\n'.join(x))
df
# Out:
# /var/folders/rf/vw4r41jd7vd95x1w0dth7v9h0000gp/T/ipykernel_32780/1278650448.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                          id                                alias  \
# 0    AQ56plNP56TIk3JswtoiMA      abbey-burger-bistro-baltimore-4
# 2    QHVUhI8JBAcqGj1JufDcHw              wiley-gunters-baltimore
# 3    DnhKT0A9OIgFdIhzNryJBw      abbey-burger-bistro-baltimore-6
# 5    S3keMV3sQjujV-oA-Ymxog           between-2-buns-baltimore-2
# 9    L_cDwPh8kuxkEP-VXjJF-A                shake-shack-baltimore
# ..                      ...                                  ...
# 522  sJOcdfLvAnnBy6Vo0ylANQ              chris-seafood-baltimore
# 523  dWI0jCoOqjge9VQTIad-Ww  york-pizza-subs-and-wings-baltimore
# 525  vnOzM6USxuhmuXV_uqg0JA                   filippos-baltimore
# 526  cA-DS-nJlfl7IYre-rjH4Q              daily-grind-baltimore-8
# 527  x6u_Xd5Zr6skcQsIUiUOng                     jazzys-baltimore
#
#                           name  \
# 0          Abbey Burger Bistro
# 2                Wiley Gunters
# 3          Abbey Burger Bistro
# 5               Between 2 Buns
# 9                  Shake Shack
# ..                         ...
# 522             Chris' Seafood
# 523  York Pizza Subs and Wings
# 525                  Filippo's
# 526                Daily Grind
# 527                    Jazzy's
#
#                                              image_url  is_closed  \
# 0    https://s3-media4.fl.yelpcdn.com/bphoto/_ZZ4nI...      False
# 2    https://s3-media3.fl.yelpcdn.com/bphoto/Lc-4k9...      False
# 3    https://s3-media3.fl.yelpcdn.com/bphoto/oq4-Iy...      False
# 5    https://s3-media1.fl.yelpcdn.com/bphoto/wfTqwH...      False
# 9    https://s3-media2.fl.yelpcdn.com/bphoto/cORtQV...      False
# ..                                                 ...        ...
# 522  https://s3-media1.fl.yelpcdn.com/bphoto/RpSPa-...      False
# 523  https://s3-media4.fl.yelpcdn.com/bphoto/Ay3jyi...      False
# 525  https://s3-media2.fl.yelpcdn.com/bphoto/NiWpYq...      False
# 526  https://s3-media1.fl.yelpcdn.com/bphoto/jrsOvc...      False
# 527  https://s3-media1.fl.yelpcdn.com/bphoto/NcDv9-...      False
#
#                                                    url  review_count  \
# 0    https://www.yelp.com/biz/abbey-burger-bistro-b...           914
# 2    https://www.yelp.com/biz/wiley-gunters-baltimo...           136
# 3    https://www.yelp.com/biz/abbey-burger-bistro-b...           266
# 5    https://www.yelp.com/biz/between-2-buns-baltim...           162
# 9    https://www.yelp.com/biz/shake-shack-baltimore...           518
# ..                                                 ...           ...
# 522  https://www.yelp.com/biz/chris-seafood-baltimo...            54
# 523  https://www.yelp.com/biz/york-pizza-subs-and-w...            49
# 525  https://www.yelp.com/biz/filippos-baltimore?ad...            51
# 526  https://www.yelp.com/biz/daily-grind-baltimore...           231
# 527  https://www.yelp.com/biz/jazzys-baltimore?adju...             1
#
#                                             categories  rating  \
# 0    [{'alias': 'sportsbars', 'title': 'Sports Bars...     4.0
# 2    [{'alias': 'burgers', 'title': 'Burgers'}, {'a...     4.5
# 3    [{'alias': 'tradamerican', 'title': 'American ...     4.0
# 5    [{'alias': 'burgers', 'title': 'Burgers'}, {'a...     3.5
# 9    [{'alias': 'newamerican', 'title': 'American (...     3.5
# ..                                                 ...     ...
# 522         [{'alias': 'seafood', 'title': 'Seafood'}]     3.5
# 523             [{'alias': 'pizza', 'title': 'Pizza'}]     2.5
# 525  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     3.0
# 526  [{'alias': 'coffee', 'title': 'Coffee & Tea'},...     3.5
# 527  [{'alias': 'burgers', 'title': 'Burgers'}, {'a...     2.0
#
#                                            coordinates  ... price  \
# 0    {'latitude': 39.2771835822848, 'longitude': -7...  ...    $$
# 2       {'latitude': 39.27174, 'longitude': -76.60223}  ...    $$
# 3    {'latitude': 39.2822776123555, 'longitude': -7...  ...    $$
# 5    {'latitude': 39.29588539090596, 'longitude': -...  ...    $$
# 9    {'latitude': 39.2867861168311, 'longitude': -7...  ...    $$
# ..                                                 ...  ...   ...
# 522  {'latitude': 39.2828178405762, 'longitude': -7...  ...    $$
# 523  {'latitude': 39.3298530578613, 'longitude': -7...  ...     $
# 525     {'latitude': 39.28699, 'longitude': -76.56748}  ...     $
# 526  {'latitude': 39.2821578979492, 'longitude': -7...  ...     $
# 527  {'latitude': 39.322087392211, 'longitude': -76...  ...   NaN
#
#                                               location         phone  \
# 0    {"address1": "1041 Marshall St", "address2": "...  1.443454e+10
# 2    {"address1": "823 E Fort Ave", "address2": "",...  1.410637e+10
# 3    {"address1": "811 S Broadway", "address2": "",...  1.410522e+10
# 5    {"address1": "520 Park Ave", "address2": "", "...  1.667303e+10
# 9    {"address1": "400 E Pratt St", "address2": "",...  1.443973e+10
# ..                                                 ...           ...
# 522  {"address1": "801 S Montford Ave", "address2":...  1.410675e+10
# 523  {"address1": "3401 Greenmount Ave", "address2"...  1.410236e+10
# 525  {"address1": "418 S Conkling St", "address2": ...  1.410327e+10
# 526  {"address1": "1720 Thames St", "address2": "",...  1.410558e+10
# 527  {"address1": "3320 Belair Rd", "address2": "",...  1.410564e+10
#
#       display_phone     distance   latitude  longitude  \
# 0    (443) 453-9698  2161.212353  39.277184 -76.612989
# 2    (410) 637-3699  2754.995467  39.271740 -76.602230
# 3    (410) 522-1428  2009.275703  39.282278 -76.592749
# 5    (667) 303-3273   931.324381  39.295885 -76.618482
# 9    (443) 973-3630  1059.381610  39.286786 -76.609732
# ..              ...          ...        ...        ...
# 522  (410) 675-0117  2628.043743  39.282818 -76.582420
# 523  (410) 235-6290  3743.767034  39.329853 -76.609146
# 525  (410) 327-4550  3607.859236  39.286990 -76.567480
# 526  (410) 558-0399  2079.005086  39.282158 -76.591797
# 527  (410) 563-6222  4134.435594  39.322087 -76.573110
#
#                                       display_location  \
# 0    {'address1': '1041 Marshall St', 'address2': '...
# 2    {'address1': '823 E Fort Ave', 'address2': '',...
# 3    {'address1': '811 S Broadway', 'address2': '',...
# 5    {'address1': '520 Park Ave', 'address2': '', '...
# 9    {'address1': '400 E Pratt St', 'address2': '',...
# ..                                                 ...
# 522  {'address1': '801 S Montford Ave', 'address2':...
# 523  {'address1': '3401 Greenmount Ave', 'address2'...
# 525  {'address1': '418 S Conkling St', 'address2': ...
# 526  {'address1': '1720 Thames St', 'address2': '',...
# 527  {'address1': '3320 Belair Rd', 'address2': '',...
#
#                                        display_address  \
# 0              [1041 Marshall St, Baltimore, MD 21230]
# 2                [823 E Fort Ave, Baltimore, MD 21230]
# 3                [811 S Broadway, Baltimore, MD 21231]
# 5    [520 Park Ave, Mount Vernon Marketplace, Balti...
# 9                [400 E Pratt St, Baltimore, MD 21202]
# ..                                                 ...
# 522          [801 S Montford Ave, Baltimore, MD 21224]
# 523         [3401 Greenmount Ave, Baltimore, MD 21218]
# 525           [418 S Conkling St, Baltimore, MD 21224]
# 526              [1720 Thames St, Baltimore, MD 21231]
# 527              [3320 Belair Rd, Baltimore, MD 21213]
#
#                                                Address
# 0                1041 Marshall St\nBaltimore, MD 21230
# 2                  823 E Fort Ave\nBaltimore, MD 21230
# 3                  811 S Broadway\nBaltimore, MD 21231
# 5    520 Park Ave\nMount Vernon Marketplace\nBaltim...
# 9                  400 E Pratt St\nBaltimore, MD 21202
# ..                                                 ...
# 522            801 S Montford Ave\nBaltimore, MD 21224
# 523           3401 Greenmount Ave\nBaltimore, MD 21218
# 525             418 S Conkling St\nBaltimore, MD 21224
# 526                1720 Thames St\nBaltimore, MD 21231
# 527                3320 Belair Rd\nBaltimore, MD 21213
#
# [318 rows x 21 columns]

# %% [markdown]
# ### Final Map

# %% [markdown]
# - Now that we have our fixed address, let's make our final map!
# - Also color-code the markers by rating!

# %%
## make ourn final map and save as varaible
pfig = px.scatter_mapbox(df, lat='latitude',lon='longitude',
                  mapbox_style='open-street-map', hover_name='name',
                         hover_data=['price','rating','Address'],
                 color='rating',
                        title='Restaurants with Burgers in Baltimore, MD')
pfig.show()
# Out:
# <div>                            <div id="a36fc296-21a8-4c58-8fde-e23f7406d424" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a36fc296-21a8-4c58-8fde-e23f7406d424")) {                    Plotly.newPlot(                        "a36fc296-21a8-4c58-8fde-e23f7406d424",                        [{"customdata":[["$$",4.0,"1041 Marshall St\nBaltimore, MD 21230"],["$$",4.5,"823 E Fort Ave\nBaltimore, MD 21230"],["$$",4.0,"811 S Broadway\nBaltimore, MD 21231"],["$$",3.5,"520 Park Ave\nMount Vernon Marketplace\nBaltimore, MD 21201"],["$$",3.5,"400 E Pratt St\nBaltimore, MD 21202"],["$$",4.5,"601 S Clinton St\nBaltimore, MD 21224"],["$$",4.0,"223 W Chase St\nBaltimore, MD 21201"],["$$",4.0,"328 N Charles St\nBaltimore, MD 21201"],["$$",4.5,"520 Park Ave\nBaltimore, MD 21201"],["$$",4.0,"1106 N Charles St\nBaltimore, MD 21201"],[null,4.0,"1065 S Charles St\nBaltimore, MD 21230"],["$",3.0,"3101 St Paul St\nBaltimore, MD 21218"],["$$",4.0,"102 Water St\nBaltimore, MD 21202"],["$$",3.5,"206 W Pratt St\nBaltimore, MD 21201"],["$",4.0,"115 N Charles St\nBaltimore, MD 21201"],["$",3.5,"1224 N Charles St\nBaltimore, MD 21201"],["$$$",4.0,"1028 S Conkling St\nBaltimore, MD 21224"],["$$",4.0,"2 N Charles St\nBaltimore, MD 21201"],["$",3.0,"410 E Baltimore St\nBaltimore, MD 21202"],["$$",4.0,"709 S Broadway\nBaltimore, MD 21231"],["$$",4.0,"2626 Hudson St\nBaltimore, MD 21224"],["$$",4.0,"735 S Broadway\nBaltimore, MD 21231"],["$$",3.5,"1 E Chase St\nBaltimore, MD 21202"],["$$",4.0,"1506 W 36th St\nBaltimore, MD 21211"],["$$",3.5,"2522 Fait Ave\nBaltimore, MD 21224"],["$$",4.5,"3728 Hudson St\nBaltimore, MD 21224"],["$",4.0,"1431 John St\nBaltimore, MD 21217"],["$$",4.0,"750 E Pratt St\nBaltimore, MD 21202"],["$$",4.5,"1622 Eastern Ave\nBaltimore, MD 21231"],[null,5.0,"31 S Calvert St\nFl 5\nThe QG\nBaltimore, MD 21202"],["$$",4.5,"213 Penn St\nBaltimore, MD 21230"],["$$",3.0,"101 W Fayette St\nBaltimore, MD 21201"],["$$",4.0,"1300 Bank St\nFl 2\nBaltimore, MD 21231"],["$$",4.0,"1939 Fleet St\nFells Point\nBaltimore, MD 21231"],["$$",4.5,"1017 W 36th St\nBaltimore, MD 21211"],["$$",4.5,"324 W Baltimore St\nBaltimore, MD 21201"],["$$",4.0,"3721 Boston St\nCanton Crossing\nBaltimore, MD 21224"],["$$",3.5,"32 Market Pl\nBaltimore, MD 21202"],["$$",4.5,"701 E Fort Ave\nBaltimore, MD 21230"],["$$",3.5,"1702 Thames St\nBaltimore, MD 21231"],["$",3.5,"829 N Charles St\nBaltimore, MD 21201"],["$$",4.5,"3626 Falls Rd\nBaltimore, MD 21211"],["$$$",4.5,"1728 Thames St\nBaltimore, MD 21231"],["$$$",4.5,"1701 N Charles St\nBaltimore, MD 21201"],["$$",3.5,"2118 Maryland Ave\nBaltimore, MD 21218"],["$$",3.5,"2100 Fleet St\nBaltimore, MD 21231"],["$$",4.0,"818 N Calvert St\nBaltimore, MD 21202"],["$$",3.5,"520 Washington Blvd\nBaltimore, MD 21230"],["$$",3.5,"504 Washington Blvd\nBaltimore, MD 21230"],["$$",3.5,"24 W Franklin St\nBaltimore, MD 21201"],["$",3.5,"227 E Baltimore St\nBaltimore, MD 21202"],["$$",4.0,"710 S Broadway\nBaltimore, MD 21231"],["$$",4.0,"1601 Union Ave\nBaltimore, MD 21211"],["$$",4.0,"203 N Paca St\nBaltimore, MD 21201"],["$",4.0,"222 N Charles St\nBaltimore, MD 21201"],["$$",4.0,"1061 S Charles St\nBaltimore, MD 21230"],["$$",3.5,"1453 Light St\nBaltimore, MD 21230"],["$$",4.5,"Baltimore, MD 21201"],["$$",3.0,"4 Market Pl\nBaltimore, MD 21202"],["$$",4.0,"421 W Baltimore St\nBaltimore, MD 21201"],["$$",3.0,"601 E Pratt St\nBaltimore, MD 21202"],["$$",4.0,"3327 St Paul St\nBaltimore, MD 21218"],[null,5.0,"226 N Gay St\nBaltimore, MD 21202"],["$$",4.0,"1236 Light St\nBaltimore, MD 21230"],["$$",4.0,"1702 Thames St\nBaltimore, MD 21231"],["$$",4.0,"511 S Caroline St\nBaltimore, MD 21231"],["$$",4.0,"10 Art Museum Dr\nBaltimore, MD 21218"],["$$",4.5,"1024 Light St\nBaltimore, MD 21230"],["$",4.5,"13 W Centre ...

# %% [markdown]
# ### HTML uses `<br>` instead of `\n`

# %%
## apply the join to every row with a lambda
df['Address'] = df['display_address'].apply(lambda x: '<br>'.join(x))
df
# Out:
# /var/folders/rf/vw4r41jd7vd95x1w0dth7v9h0000gp/T/ipykernel_32780/1844012891.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                          id                                alias  \
# 0    AQ56plNP56TIk3JswtoiMA      abbey-burger-bistro-baltimore-4
# 2    QHVUhI8JBAcqGj1JufDcHw              wiley-gunters-baltimore
# 3    DnhKT0A9OIgFdIhzNryJBw      abbey-burger-bistro-baltimore-6
# 5    S3keMV3sQjujV-oA-Ymxog           between-2-buns-baltimore-2
# 9    L_cDwPh8kuxkEP-VXjJF-A                shake-shack-baltimore
# ..                      ...                                  ...
# 522  sJOcdfLvAnnBy6Vo0ylANQ              chris-seafood-baltimore
# 523  dWI0jCoOqjge9VQTIad-Ww  york-pizza-subs-and-wings-baltimore
# 525  vnOzM6USxuhmuXV_uqg0JA                   filippos-baltimore
# 526  cA-DS-nJlfl7IYre-rjH4Q              daily-grind-baltimore-8
# 527  x6u_Xd5Zr6skcQsIUiUOng                     jazzys-baltimore
#
#                           name  \
# 0          Abbey Burger Bistro
# 2                Wiley Gunters
# 3          Abbey Burger Bistro
# 5               Between 2 Buns
# 9                  Shake Shack
# ..                         ...
# 522             Chris' Seafood
# 523  York Pizza Subs and Wings
# 525                  Filippo's
# 526                Daily Grind
# 527                    Jazzy's
#
#                                              image_url  is_closed  \
# 0    https://s3-media4.fl.yelpcdn.com/bphoto/_ZZ4nI...      False
# 2    https://s3-media3.fl.yelpcdn.com/bphoto/Lc-4k9...      False
# 3    https://s3-media3.fl.yelpcdn.com/bphoto/oq4-Iy...      False
# 5    https://s3-media1.fl.yelpcdn.com/bphoto/wfTqwH...      False
# 9    https://s3-media2.fl.yelpcdn.com/bphoto/cORtQV...      False
# ..                                                 ...        ...
# 522  https://s3-media1.fl.yelpcdn.com/bphoto/RpSPa-...      False
# 523  https://s3-media4.fl.yelpcdn.com/bphoto/Ay3jyi...      False
# 525  https://s3-media2.fl.yelpcdn.com/bphoto/NiWpYq...      False
# 526  https://s3-media1.fl.yelpcdn.com/bphoto/jrsOvc...      False
# 527  https://s3-media1.fl.yelpcdn.com/bphoto/NcDv9-...      False
#
#                                                    url  review_count  \
# 0    https://www.yelp.com/biz/abbey-burger-bistro-b...           914
# 2    https://www.yelp.com/biz/wiley-gunters-baltimo...           136
# 3    https://www.yelp.com/biz/abbey-burger-bistro-b...           266
# 5    https://www.yelp.com/biz/between-2-buns-baltim...           162
# 9    https://www.yelp.com/biz/shake-shack-baltimore...           518
# ..                                                 ...           ...
# 522  https://www.yelp.com/biz/chris-seafood-baltimo...            54
# 523  https://www.yelp.com/biz/york-pizza-subs-and-w...            49
# 525  https://www.yelp.com/biz/filippos-baltimore?ad...            51
# 526  https://www.yelp.com/biz/daily-grind-baltimore...           231
# 527  https://www.yelp.com/biz/jazzys-baltimore?adju...             1
#
#                                             categories  rating  \
# 0    [{'alias': 'sportsbars', 'title': 'Sports Bars...     4.0
# 2    [{'alias': 'burgers', 'title': 'Burgers'}, {'a...     4.5
# 3    [{'alias': 'tradamerican', 'title': 'American ...     4.0
# 5    [{'alias': 'burgers', 'title': 'Burgers'}, {'a...     3.5
# 9    [{'alias': 'newamerican', 'title': 'American (...     3.5
# ..                                                 ...     ...
# 522         [{'alias': 'seafood', 'title': 'Seafood'}]     3.5
# 523             [{'alias': 'pizza', 'title': 'Pizza'}]     2.5
# 525  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     3.0
# 526  [{'alias': 'coffee', 'title': 'Coffee & Tea'},...     3.5
# 527  [{'alias': 'burgers', 'title': 'Burgers'}, {'a...     2.0
#
#                                            coordinates  ... price  \
# 0    {'latitude': 39.2771835822848, 'longitude': -7...  ...    $$
# 2       {'latitude': 39.27174, 'longitude': -76.60223}  ...    $$
# 3    {'latitude': 39.2822776123555, 'longitude': -7...  ...    $$
# 5    {'latitude': 39.29588539090596, 'longitude': -...  ...    $$
# 9    {'latitude': 39.2867861168311, 'longitude': -7...  ...    $$
# ..                                                 ...  ...   ...
# 522  {'latitude': 39.2828178405762, 'longitude': -7...  ...    $$
# 523  {'latitude': 39.3298530578613, 'longitude': -7...  ...     $
# 525     {'latitude': 39.28699, 'longitude': -76.56748}  ...     $
# 526  {'latitude': 39.2821578979492, 'longitude': -7...  ...     $
# 527  {'latitude': 39.322087392211, 'longitude': -76...  ...   NaN
#
#                                               location         phone  \
# 0    {"address1": "1041 Marshall St", "address2": "...  1.443454e+10
# 2    {"address1": "823 E Fort Ave", "address2": "",...  1.410637e+10
# 3    {"address1": "811 S Broadway", "address2": "",...  1.410522e+10
# 5    {"address1": "520 Park Ave", "address2": "", "...  1.667303e+10
# 9    {"address1": "400 E Pratt St", "address2": "",...  1.443973e+10
# ..                                                 ...           ...
# 522  {"address1": "801 S Montford Ave", "address2":...  1.410675e+10
# 523  {"address1": "3401 Greenmount Ave", "address2"...  1.410236e+10
# 525  {"address1": "418 S Conkling St", "address2": ...  1.410327e+10
# 526  {"address1": "1720 Thames St", "address2": "",...  1.410558e+10
# 527  {"address1": "3320 Belair Rd", "address2": "",...  1.410564e+10
#
#       display_phone     distance   latitude  longitude  \
# 0    (443) 453-9698  2161.212353  39.277184 -76.612989
# 2    (410) 637-3699  2754.995467  39.271740 -76.602230
# 3    (410) 522-1428  2009.275703  39.282278 -76.592749
# 5    (667) 303-3273   931.324381  39.295885 -76.618482
# 9    (443) 973-3630  1059.381610  39.286786 -76.609732
# ..              ...          ...        ...        ...
# 522  (410) 675-0117  2628.043743  39.282818 -76.582420
# 523  (410) 235-6290  3743.767034  39.329853 -76.609146
# 525  (410) 327-4550  3607.859236  39.286990 -76.567480
# 526  (410) 558-0399  2079.005086  39.282158 -76.591797
# 527  (410) 563-6222  4134.435594  39.322087 -76.573110
#
#                                       display_location  \
# 0    {'address1': '1041 Marshall St', 'address2': '...
# 2    {'address1': '823 E Fort Ave', 'address2': '',...
# 3    {'address1': '811 S Broadway', 'address2': '',...
# 5    {'address1': '520 Park Ave', 'address2': '', '...
# 9    {'address1': '400 E Pratt St', 'address2': '',...
# ..                                                 ...
# 522  {'address1': '801 S Montford Ave', 'address2':...
# 523  {'address1': '3401 Greenmount Ave', 'address2'...
# 525  {'address1': '418 S Conkling St', 'address2': ...
# 526  {'address1': '1720 Thames St', 'address2': '',...
# 527  {'address1': '3320 Belair Rd', 'address2': '',...
#
#                                        display_address  \
# 0              [1041 Marshall St, Baltimore, MD 21230]
# 2                [823 E Fort Ave, Baltimore, MD 21230]
# 3                [811 S Broadway, Baltimore, MD 21231]
# 5    [520 Park Ave, Mount Vernon Marketplace, Balti...
# 9                [400 E Pratt St, Baltimore, MD 21202]
# ..                                                 ...
# 522          [801 S Montford Ave, Baltimore, MD 21224]
# 523         [3401 Greenmount Ave, Baltimore, MD 21218]
# 525           [418 S Conkling St, Baltimore, MD 21224]
# 526              [1720 Thames St, Baltimore, MD 21231]
# 527              [3320 Belair Rd, Baltimore, MD 21213]
#
#                                                Address
# 0              1041 Marshall St<br>Baltimore, MD 21230
# 2                823 E Fort Ave<br>Baltimore, MD 21230
# 3                811 S Broadway<br>Baltimore, MD 21231
# 5    520 Park Ave<br>Mount Vernon Marketplace<br>Ba...
# 9                400 E Pratt St<br>Baltimore, MD 21202
# ..                                                 ...
# 522          801 S Montford Ave<br>Baltimore, MD 21224
# 523         3401 Greenmount Ave<br>Baltimore, MD 21218
# 525           418 S Conkling St<br>Baltimore, MD 21224
# 526              1720 Thames St<br>Baltimore, MD 21231
# 527              3320 Belair Rd<br>Baltimore, MD 21213
#
# [318 rows x 21 columns]

# %%
## make ourn final map and save as varaible
pfig = px.scatter_mapbox(df, lat='latitude',lon='longitude',
                  mapbox_style='open-street-map', hover_name='name',
                         hover_data=['price','rating','Address'],
                 color='rating',
                        title='Restaurants with Burgers in Baltimore, MD')
pfig.show()
# Out:
# <div>                            <div id="804f37da-ab92-4b35-b27d-b771bf0be3b1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("804f37da-ab92-4b35-b27d-b771bf0be3b1")) {                    Plotly.newPlot(                        "804f37da-ab92-4b35-b27d-b771bf0be3b1",                        [{"customdata":[["$$",4.0,"1041 Marshall St<br>Baltimore, MD 21230"],["$$",4.5,"823 E Fort Ave<br>Baltimore, MD 21230"],["$$",4.0,"811 S Broadway<br>Baltimore, MD 21231"],["$$",3.5,"520 Park Ave<br>Mount Vernon Marketplace<br>Baltimore, MD 21201"],["$$",3.5,"400 E Pratt St<br>Baltimore, MD 21202"],["$$",4.5,"601 S Clinton St<br>Baltimore, MD 21224"],["$$",4.0,"223 W Chase St<br>Baltimore, MD 21201"],["$$",4.0,"328 N Charles St<br>Baltimore, MD 21201"],["$$",4.5,"520 Park Ave<br>Baltimore, MD 21201"],["$$",4.0,"1106 N Charles St<br>Baltimore, MD 21201"],[null,4.0,"1065 S Charles St<br>Baltimore, MD 21230"],["$",3.0,"3101 St Paul St<br>Baltimore, MD 21218"],["$$",4.0,"102 Water St<br>Baltimore, MD 21202"],["$$",3.5,"206 W Pratt St<br>Baltimore, MD 21201"],["$",4.0,"115 N Charles St<br>Baltimore, MD 21201"],["$",3.5,"1224 N Charles St<br>Baltimore, MD 21201"],["$$$",4.0,"1028 S Conkling St<br>Baltimore, MD 21224"],["$$",4.0,"2 N Charles St<br>Baltimore, MD 21201"],["$",3.0,"410 E Baltimore St<br>Baltimore, MD 21202"],["$$",4.0,"709 S Broadway<br>Baltimore, MD 21231"],["$$",4.0,"2626 Hudson St<br>Baltimore, MD 21224"],["$$",4.0,"735 S Broadway<br>Baltimore, MD 21231"],["$$",3.5,"1 E Chase St<br>Baltimore, MD 21202"],["$$",4.0,"1506 W 36th St<br>Baltimore, MD 21211"],["$$",3.5,"2522 Fait Ave<br>Baltimore, MD 21224"],["$$",4.5,"3728 Hudson St<br>Baltimore, MD 21224"],["$",4.0,"1431 John St<br>Baltimore, MD 21217"],["$$",4.0,"750 E Pratt St<br>Baltimore, MD 21202"],["$$",4.5,"1622 Eastern Ave<br>Baltimore, MD 21231"],[null,5.0,"31 S Calvert St<br>Fl 5<br>The QG<br>Baltimore, MD 21202"],["$$",4.5,"213 Penn St<br>Baltimore, MD 21230"],["$$",3.0,"101 W Fayette St<br>Baltimore, MD 21201"],["$$",4.0,"1300 Bank St<br>Fl 2<br>Baltimore, MD 21231"],["$$",4.0,"1939 Fleet St<br>Fells Point<br>Baltimore, MD 21231"],["$$",4.5,"1017 W 36th St<br>Baltimore, MD 21211"],["$$",4.5,"324 W Baltimore St<br>Baltimore, MD 21201"],["$$",4.0,"3721 Boston St<br>Canton Crossing<br>Baltimore, MD 21224"],["$$",3.5,"32 Market Pl<br>Baltimore, MD 21202"],["$$",4.5,"701 E Fort Ave<br>Baltimore, MD 21230"],["$$",3.5,"1702 Thames St<br>Baltimore, MD 21231"],["$",3.5,"829 N Charles St<br>Baltimore, MD 21201"],["$$",4.5,"3626 Falls Rd<br>Baltimore, MD 21211"],["$$$",4.5,"1728 Thames St<br>Baltimore, MD 21231"],["$$$",4.5,"1701 N Charles St<br>Baltimore, MD 21201"],["$$",3.5,"2118 Maryland Ave<br>Baltimore, MD 21218"],["$$",3.5,"2100 Fleet St<br>Baltimore, MD 21231"],["$$",4.0,"818 N Calvert St<br>Baltimore, MD 21202"],["$$",3.5,"520 Washington Blvd<br>Baltimore, MD 21230"],["$$",3.5,"504 Washington Blvd<br>Baltimore, MD 21230"],["$$",3.5,"24 W Franklin St<br>Baltimore, MD 21201"],["$",3.5,"227 E Baltimore St<br>Baltimore, MD 21202"],["$$",4.0,"710 S Broadway<br>Baltimore, MD 21231"],["$$",4.0,"1601 Union Ave<br>Baltimore, MD 21211"],["$$",4.0,"203 N Paca St<br>Baltimore, MD 21201"],["$",4.0,"222 N Charles St<br>Baltimore, MD 21201"],["$$",4.0,"1061 S Charles St<br>Baltimore, MD 21230"],["$$",3.5,"1453 Light St<br>Baltimore, MD 21230"],["$$",4.5,"Baltimore, MD 21201"],["$$",3.0,"4 Market Pl<br>Baltimore, MD 21202"],["$$",4.0,"421 W Baltimore St<br>Baltimore, MD 21201"],["$$",3.0,"601 E Pratt St<br>Baltimore, MD 21202"],["$$",4.0,"3327 St Paul St<br>Baltimore, MD 21218"],[null,5.0,"226 N Gay St<br>Baltimore, MD 21202"],["$$",4.0,"1236 Light St<br>Baltimore, MD 21230"],["$$",4.0,"1702 Thames St<br>Baltimore, MD 21231"],["$$",4.0,"511 S Caroline St<br> ...

# %%
## use fig.write_html to save map
pfig.write_html('local_yelp_results.html')

# %% [markdown]
# # APPENDIX

# %%
## using hover_data to turn off lat/long
hover_data={'price':True,'rating':True,
             'Address':True,
             'latitude':False,
            'longitude':False}

pfig = px.scatter_mapbox(df, lat='latitude',lon='longitude',
                  mapbox_style='open-street-map', hover_name='name',
                         hover_data=hover_data,
                 color='rating',
                        title='Restaurants with Burgers in Baltimore, MD')
pfig.show()
# Out:
# <div>                            <div id="a8daab82-0032-467f-bb43-a77d565e1e35" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a8daab82-0032-467f-bb43-a77d565e1e35")) {                    Plotly.newPlot(                        "a8daab82-0032-467f-bb43-a77d565e1e35",                        [{"customdata":[["$$",4.0,"1041 Marshall St<br>Baltimore, MD 21230",39.2771835822848,-76.6129885794452],["$$",4.5,"823 E Fort Ave<br>Baltimore, MD 21230",39.27174,-76.60223],["$$",4.0,"811 S Broadway<br>Baltimore, MD 21231",39.2822776123555,-76.5927489101887],["$$",3.5,"520 Park Ave<br>Mount Vernon Marketplace<br>Baltimore, MD 21201",39.29588539090596,-76.61848222083206],["$$",3.5,"400 E Pratt St<br>Baltimore, MD 21202",39.2867861168311,-76.609731923838],["$$",4.5,"601 S Clinton St<br>Baltimore, MD 21224",39.28538,-76.56961],["$$",4.0,"223 W Chase St<br>Baltimore, MD 21201",39.3016090393066,-76.6189498901367],["$$",4.0,"328 N Charles St<br>Baltimore, MD 21201",39.293462,-76.615586],["$$",4.5,"520 Park Ave<br>Baltimore, MD 21201",39.295902,-76.618819],["$$",4.0,"1106 N Charles St<br>Baltimore, MD 21201",39.302825295486,-76.616179918669],[null,4.0,"1065 S Charles St<br>Baltimore, MD 21230",39.276819,-76.613262],["$",3.0,"3101 St Paul St<br>Baltimore, MD 21218",39.3259602,-76.6155321],["$$",4.0,"102 Water St<br>Baltimore, MD 21202",39.288553,-76.613303],["$$",3.5,"206 W Pratt St<br>Baltimore, MD 21201",39.2865982055664,-76.6181564331055],["$",4.0,"115 N Charles St<br>Baltimore, MD 21201",39.2905746,-76.6150372],["$",3.5,"1224 N Charles St<br>Baltimore, MD 21201",39.304130942601,-76.6163050999271],["$$$",4.0,"1028 S Conkling St<br>Baltimore, MD 21224",39.280742,-76.566986],["$$",4.0,"2 N Charles St<br>Baltimore, MD 21201",39.2899436853933,-76.6153600656067],["$",3.0,"410 E Baltimore St<br>Baltimore, MD 21202",39.2898726,-76.6099701],["$$",4.0,"709 S Broadway<br>Baltimore, MD 21231",39.2832841,-76.5930668],["$$",4.0,"2626 Hudson St<br>Baltimore, MD 21224",39.2822084,-76.578824],["$$",4.0,"735 S Broadway<br>Baltimore, MD 21231",39.282672,-76.5929910484795],["$$",3.5,"1 E Chase St<br>Baltimore, MD 21202",39.3019803748168,-76.6154620257255],["$$",4.0,"1506 W 36th St<br>Baltimore, MD 21211",39.3299578395486,-76.6394938135723],["$$",3.5,"2522 Fait Ave<br>Baltimore, MD 21224",39.2832024,-76.5804507],["$$",4.5,"3728 Hudson St<br>Baltimore, MD 21224",39.28281,-76.56513],["$",4.0,"1431 John St<br>Baltimore, MD 21217",39.30839753480792,-76.62382874530032],["$$",4.0,"750 E Pratt St<br>Baltimore, MD 21202",39.2870995,-76.6053657],["$$",4.5,"1622 Eastern Ave<br>Baltimore, MD 21231",39.2857429,-76.594557],[null,5.0,"31 S Calvert St<br>Fl 5<br>The QG<br>Baltimore, MD 21202",39.28807,-76.61196],["$$",4.5,"213 Penn St<br>Baltimore, MD 21230",39.285576,-76.625679],["$$",3.0,"101 W Fayette St<br>Baltimore, MD 21201",39.29021546895015,-76.61712548230565],["$$",4.0,"1300 Bank St<br>Fl 2<br>Baltimore, MD 21231",39.2864826376183,-76.5989464422474],["$$",4.0,"1939 Fleet St<br>Fells Point<br>Baltimore, MD 21231",39.2845344543457,-76.5888671875],["$$",4.5,"1017 W 36th St<br>Baltimore, MD 21211",39.3310122069348,-76.6331992056355],["$$",4.5,"324 W Baltimore St<br>Baltimore, MD 21201",39.289519,-76.620653],["$$",4.0,"3721 Boston St<br>Canton Crossing<br>Baltimore, MD 21224",39.2764795638087,-76.5653344920654],["$$",3.5,"32 Market Pl<br>Baltimore, MD 21202",39.2889121,-76.6072119],["$$",4.5,"701 E Fort Ave<br>Baltimore, MD 21230",39.2723872853157,-76.6039957478642],["$$",3.5,"1702 Thames St<br>Baltimore, MD 21231",39.2819529,-76.5925098],["$",3.5,"829 N Charles St<br>Baltimore, MD 21201",39.2995431,-76.6154524],["$$",4.5,"3626 Falls Rd<br>Baltimore, MD 21211",39.3314348,-76.6352768],["$$$",4.5,"1728 Thames St<br>Baltimore, MD 21231",39.2821 ...
